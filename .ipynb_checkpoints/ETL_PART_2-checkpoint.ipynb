# %% [markdown]
# # Description -:
#
# 1. In This Jupyter Notebook Data cleaning was done only for year 2018-2023.
#
# 2. We used the data exported from ETL_PART_1 to maintain the data consistent over all of the years.
#
# 2. After cleaning the data, It was exported yearwise as CSV files for the Years 2015-2023.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Reading the Data exported from ETL_PART_ONE to resources folder.
df1 = pd.read_csv("./resources/wh_2015.csv")
df2 = pd.read_csv("./resources/wh_2016.csv")
df3 = pd.read_csv("./resources/wh_2017.csv")
# Reading the CSVs for year 2018-2023 downloaded from Kaggle
df4 = pd.read_csv("./resources/2018.csv")
df5 = pd.read_csv("./resources/2019.csv")
df6 = pd.read_csv("./resources/2020.csv")
df7 = pd.read_csv("./resources/2021.csv")
df8 = pd.read_csv("./resources/2022.csv")
df9 = pd.read_csv("./resources/2023.csv")

# %%
df4.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
df4.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df4 = df4.rename({
    'Country or region':'country',
    'Overall rank': 'happiness_rank',
    'Score':'happiness_score',
    'GDP per capita':'gdp_per_capita',
    'Social support':'social_support',
    'Healthy life expectancy':'life_expectancy',
    'Freedom to make life choices':'freedom_to_make_life_choices',
    'Generosity':'generosity',
    'Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df4.head()
# Out:
#    happiness_rank      country  happiness_score  gdp_per_capita  \
# 0               1      Finland            7.632           1.305
# 1               2       Norway            7.594           1.456
# 2               3      Denmark            7.555           1.351
# 3               4      Iceland            7.495           1.343
# 4               5  Switzerland            7.487           1.420
#
#    social_support  life_expectancy  freedom_to_make_life_choices  generosity  \
# 0           1.592            0.874                         0.681       0.202
# 1           1.582            0.861                         0.686       0.286
# 2           1.590            0.868                         0.683       0.284
# 3           1.644            0.914                         0.677       0.353
# 4           1.549            0.927                         0.660       0.256
#
#    perceptions_of_corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
duplicate_rows = df4[df4.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [happiness_rank, country, happiness_score, gdp_per_capita, social_support, life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption]
# Index: []

# %%
df5.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
duplicate_rows = df5[df5.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
df5 = df5.rename({
    'Country or region':'country',
    'Overall rank': 'happiness_rank',
    'Score':'happiness_score',
    'GDP per capita':'gdp_per_capita',
    'Social support':'social_support',
    'Healthy life expectancy':'life_expectancy',
    'Freedom to make life choices':'freedom_to_make_life_choices',
    'Generosity':'generosity',
    'Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df5.head(1)
# Out:
#    happiness_rank  country  happiness_score  gdp_per_capita  social_support  \
# 0               1  Finland            7.769            1.34           1.587
#
#    life_expectancy  freedom_to_make_life_choices  generosity  \
# 0            0.986                         0.596       0.153
#
#    perceptions_of_corruption
# 0                      0.393

# %% [markdown]
# # Cleaning the data to keep the common countries data in years 2015, 2018 and 2019

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df4['country']) &
    df1['country'].isin(df5['country'])
)
# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df4 = df4[df4['country'].isin(df1['country'])]
df5 = df5[df5['country'].isin(df1['country'])]

# %%
df1
# Out:
#          country    region          sub_region iso_alpha  happiness_score  \
# 0    Switzerland    Europe      Western Europe       CHE            7.587
# 1        Iceland    Europe     Northern Europe       ISL            7.561
# 2        Denmark    Europe     Northern Europe       DNK            7.527
# 3         Norway    Europe     Northern Europe       NOR            7.522
# 4         Canada  Americas    Northern America       CAN            7.427
# ..           ...       ...                 ...       ...              ...
# 134       Rwanda    Africa  Sub-Saharan Africa       RWA            3.465
# 135        Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 136        Syria      Asia        Western Asia       SYR            3.006
# 137      Burundi    Africa  Sub-Saharan Africa       BDI            2.905
# 138         Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 134         0.22208         0.77370          0.42864
# 135         0.28665         0.35386          0.31910
# 136         0.66320         0.47489          0.72193
# 137         0.01530         0.41587          0.22396
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 134                       0.59201     0.22628                    0.55191
# 135                       0.48450     0.18260                    0.08010
# 136                       0.15684     0.47179                    0.18906
# 137                       0.11850     0.19727                    0.10062
# 138                       0.36453     0.16681                    0.10731
#
# [135 rows x 11 columns]

# %%
df4
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.632           1.305
# 1                 2       Norway            7.594           1.456
# 2                 3      Denmark            7.555           1.351
# 3                 4      Iceland            7.495           1.343
# 4                 5  Switzerland            7.487           1.420
# ..              ...          ...              ...             ...
# 149             150        Syria            3.462           0.689
# 150             151       Rwanda            3.408           0.332
# 151             152        Yemen            3.355           0.442
# 152             153     Tanzania            3.303           0.455
# 155             156      Burundi            2.905           0.091
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.592            0.874                         0.681
# 1             1.582            0.861                         0.686
# 2             1.590            0.868                         0.683
# 3             1.644            0.914                         0.677
# 4             1.549            0.927                         0.660
# ..              ...              ...                           ...
# 149           0.382            0.539                         0.088
# 150           0.896            0.400                         0.636
# 151           1.073            0.343                         0.244
# 152           0.991            0.381                         0.481
# 155           0.627            0.145                         0.065
#
#      generosity  perceptions_of_corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 149       0.376                      0.144
# 150       0.200                      0.444
# 151       0.083                      0.064
# 152       0.270                      0.097
# 155       0.149                      0.076
#
# [135 rows x 9 columns]

# %%
df5
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.769           1.340
# 1                 2      Denmark            7.600           1.383
# 2                 3       Norway            7.554           1.488
# 3                 4      Iceland            7.494           1.380
# 4                 5  Netherlands            7.488           1.396
# ..              ...          ...              ...             ...
# 149             150       Malawi            3.410           0.191
# 150             151        Yemen            3.380           0.287
# 151             152       Rwanda            3.334           0.359
# 152             153     Tanzania            3.231           0.476
# 153             154  Afghanistan            3.203           0.350
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.587            0.986                         0.596
# 1             1.573            0.996                         0.592
# 2             1.582            1.028                         0.603
# 3             1.624            1.026                         0.591
# 4             1.522            0.999                         0.557
# ..              ...              ...                           ...
# 149           0.560            0.495                         0.443
# 150           1.163            0.463                         0.143
# 151           0.711            0.614                         0.555
# 152           0.885            0.499                         0.417
# 153           0.517            0.361                         0.000
#
#      generosity  perceptions_of_corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 149       0.218                      0.089
# 150       0.108                      0.077
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
#
# [135 rows x 9 columns]

# %%
df6.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                           1.28519
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                 0.477857             2.762835

# %%
df6 = df6.drop(columns=['Regional indicator',
                        'Standard error of ladder score',
                        'upperwhisker',
                        'lowerwhisker',
                        'Logged GDP per capita',
                        'Social support',
                        'Freedom to make life choices',
                        'Generosity',
                        'Ladder score in Dystopia',
                        'Explained by: Healthy life expectancy',
                        'Explained by: Perceptions of corruption',
                        'Dystopia + residual'],axis=1)

# %%
df6.head(1)
# Out:
#   Country name  Ladder score  Healthy life expectancy  \
# 0      Finland        7.8087                71.900825
#
#    Perceptions of corruption  Explained by: Log GDP per capita  \
# 0                   0.195445                           1.28519
#
#    Explained by: Social support  Explained by: Freedom to make life choices  \
# 0                      1.499526                                    0.662317
#
#    Explained by: Generosity
# 0                   0.15967

# %%
#Rename the columns for consistency
df6 = df6.rename({
    'Country name':'country',
    'Ladder score':'happiness_score',
    'Explained by: Log GDP per capita':'gdp_per_capita',
    'Explained by: Social support':'social_support',
    'Healthy life expectancy':'life_expectancy',
    'Explained by: Freedom to make life choices':'freedom_to_make_life_choices',
    'Explained by: Generosity':'generosity',
    'Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df6.head()
# Out:
#        country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0      Finland           7.8087        71.900825                   0.195445
# 1      Denmark           7.6456        72.402504                   0.168489
# 2  Switzerland           7.5599        74.102448                   0.303728
# 3      Iceland           7.5045        73.000000                   0.711710
# 4       Norway           7.4880        73.200783                   0.263218
#
#    gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0        1.285190        1.499526                      0.662317    0.159670
# 1        1.326949        1.503449                      0.665040    0.242793
# 2        1.390774        1.472403                      0.628954    0.269056
# 3        1.326502        1.547567                      0.661981    0.362330
# 4        1.424207        1.495173                      0.670201    0.287985

# %%
duplicate_rows = df6[df6.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [country, happiness_score, life_expectancy, perceptions_of_corruption, gdp_per_capita, social_support, freedom_to_make_life_choices, generosity]
# Index: []

# %%
df7.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253

# %%
df7 = df7.drop(columns=['Regional indicator',
                        'Standard error of ladder score',
                        'upperwhisker',
                        'lowerwhisker',
                        'Logged GDP per capita',
                        'Social support',
                        'Freedom to make life choices',
                        'Generosity',
                        'Ladder score in Dystopia',
                        'Explained by: Healthy life expectancy',
                        'Explained by: Perceptions of corruption',
                        'Dystopia + residual'],axis=1)

# %%
df7.head(1)
# Out:
#   Country name  Ladder score  Healthy life expectancy  \
# 0      Finland         7.842                     72.0
#
#    Perceptions of corruption  Explained by: Log GDP per capita  \
# 0                      0.186                             1.446
#
#    Explained by: Social support  Explained by: Freedom to make life choices  \
# 0                         1.106                                       0.691
#
#    Explained by: Generosity
# 0                     0.124

# %%
#Rename the columns for consistency
df7 = df7.rename({
    'Country name':'country',
    'Ladder score':'happiness_score',
    'Explained by: Log GDP per capita':'gdp_per_capita',
    'Explained by: Social support':'social_support',
    'Healthy life expectancy':'life_expectancy',
    'Explained by: Freedom to make life choices':'freedom_to_make_life_choices',
    'Explained by: Generosity':'generosity',
    'Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df7.head()
# Out:
#        country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0      Finland            7.842             72.0                      0.186
# 1      Denmark            7.620             72.7                      0.179
# 2  Switzerland            7.571             74.4                      0.292
# 3      Iceland            7.554             73.0                      0.673
# 4  Netherlands            7.464             72.4                      0.338
#
#    gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0           1.446           1.106                         0.691       0.124
# 1           1.502           1.108                         0.686       0.208
# 2           1.566           1.079                         0.653       0.204
# 3           1.482           1.172                         0.698       0.293
# 4           1.501           1.079                         0.647       0.302

# %%
duplicate_rows = df7[df7.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [country, happiness_score, life_expectancy, perceptions_of_corruption, gdp_per_capita, social_support, freedom_to_make_life_choices, generosity]
# Index: []

# %% [markdown]
# # Cleaning the data to keep the common countries data in years 2015, 2020 and 2021

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df6['country']) &
    df1['country'].isin(df7['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df6 = df6[df6['country'].isin(df1['country'])]
df7 = df7[df7['country'].isin(df1['country'])]

# %%
df1
# Out:
#          country    region          sub_region iso_alpha  happiness_score  \
# 0    Switzerland    Europe      Western Europe       CHE            7.587
# 1        Iceland    Europe     Northern Europe       ISL            7.561
# 2        Denmark    Europe     Northern Europe       DNK            7.527
# 3         Norway    Europe     Northern Europe       NOR            7.522
# 4         Canada  Americas    Northern America       CAN            7.427
# ..           ...       ...                 ...       ...              ...
# 133  Afghanistan      Asia       Southern Asia       AFG            3.575
# 134       Rwanda    Africa  Sub-Saharan Africa       RWA            3.465
# 135        Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 137      Burundi    Africa  Sub-Saharan Africa       BDI            2.905
# 138         Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 133         0.31982         0.30285          0.30335
# 134         0.22208         0.77370          0.42864
# 135         0.28665         0.35386          0.31910
# 137         0.01530         0.41587          0.22396
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 133                       0.23414     0.36510                    0.09719
# 134                       0.59201     0.22628                    0.55191
# 135                       0.48450     0.18260                    0.08010
# 137                       0.11850     0.19727                    0.10062
# 138                       0.36453     0.16681                    0.10731
#
# [132 rows x 11 columns]

# %%
df6
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland           7.8087        71.900825                   0.195445
# 1        Denmark           7.6456        72.402504                   0.168489
# 2    Switzerland           7.5599        74.102448                   0.303728
# 3        Iceland           7.5045        73.000000                   0.711710
# 4         Norway           7.4880        73.200783                   0.263218
# ..           ...              ...              ...                        ...
# 146     Botswana           3.4789        58.924454                   0.777931
# 147     Tanzania           3.4762        57.496075                   0.619799
# 149       Rwanda           3.3123        61.098846                   0.183541
# 150     Zimbabwe           3.2992        55.617260                   0.810237
# 152  Afghanistan           2.5669        52.590000                   0.933687
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0          1.285190        1.499526                      0.662317    0.159670
# 1          1.326949        1.503449                      0.665040    0.242793
# 2          1.390774        1.472403                      0.628954    0.269056
# 3          1.326502        1.547567                      0.661981    0.362330
# 4          1.424207        1.495173                      0.670201    0.287985
# ..              ...             ...                           ...         ...
# 146        0.997549        1.085695                      0.509089    0.033407
# 147        0.457163        0.872675                      0.509343    0.271541
# 149        0.343243        0.522876                      0.604088    0.235705
# 150        0.425564        1.047835                      0.377405    0.151349
# 152        0.300706        0.356434                      0.000000    0.135235
#
# [132 rows x 8 columns]

# %%
df7.dtypes
# Out:
# country                          object
# happiness_score                 float64
# life_expectancy                 float64
# perceptions_of_corruption       float64
# gdp_per_capita                  float64
# social_support                  float64
# freedom_to_make_life_choices    float64
# generosity                      float64
# dtype: object

# %%
df8.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# 2                        1,320                                 0,803
# 3                        1,226                                 0,822
# 4                        1,206                                 0,787
#
#   Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                      0,736                    0,109
# 1                                      0,719                    0,188
# 2                                      0,718                    0,270
# 3                                      0,677                    0,147
# 4                                      0,651                    0,271
#
#   Explained by: Perceptions of corruption
# 0                                   0,534
# 1                                   0,532
# 2                                   0,191
# 3                                   0,461
# 4                                   0,419

# %%
df8 = df8.drop(columns=['RANK',
                        'Whisker-high',
                        'Whisker-low',
                        'Dystopia (1.83) + residual'
                        ],axis=1)

# %%
df8.head(1)
# Out:
#    Country Happiness score Explained by: GDP per capita  \
# 0  Finland           7,821                        1,892
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
#
#   Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                      0,736                    0,109
#
#   Explained by: Perceptions of corruption
# 0                                   0,534

# %%
#Rename the columns for consistency
df8 = df8.rename({
    'Country':'country',
    'Happiness score':'happiness_score',
    'Explained by: GDP per capita':'gdp_per_capita',
    'Explained by: Social support':'social_support',
    'Explained by: Healthy life expectancy':'life_expectancy',
    'Explained by: Freedom to make life choices':'freedom_to_make_life_choices',
    'Explained by: Generosity':'generosity',
    'Explained by: Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df8.head()
# Out:
#        country happiness_score gdp_per_capita social_support life_expectancy  \
# 0      Finland           7,821          1,892          1,258           0,775
# 1      Denmark           7,636          1,953          1,243           0,777
# 2      Iceland           7,557          1,936          1,320           0,803
# 3  Switzerland           7,512          2,026          1,226           0,822
# 4  Netherlands           7,415          1,945          1,206           0,787
#
#   freedom_to_make_life_choices generosity perceptions_of_corruption
# 0                        0,736      0,109                     0,534
# 1                        0,719      0,188                     0,532
# 2                        0,718      0,270                     0,191
# 3                        0,677      0,147                     0,461
# 4                        0,651      0,271                     0,419

# %%
df8['happiness_score'] = df8['happiness_score'].str.replace(',', '.').astype(float)
df8['gdp_per_capita'] = df8['gdp_per_capita'].str.replace(',', '.').astype(float)
df8['social_support'] = df8['social_support'].str.replace(',', '.').astype(float)
df8['life_expectancy'] = df8['life_expectancy'].str.replace(',', '.').astype(float)
df8['freedom_to_make_life_choices'] = df8['freedom_to_make_life_choices'].str.replace(',', '.').astype(float)
df8['generosity'] = df8['generosity'].str.replace(',', '.').astype(float)
df8['perceptions_of_corruption'] = df8['perceptions_of_corruption'].str.replace(',', '.').astype(float)
df8.head(1)
# Out:
#    country  happiness_score  gdp_per_capita  social_support  life_expectancy  \
# 0  Finland            7.821           1.892           1.258            0.775
#
#    freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.736       0.109                      0.534

# %%
df8.dtypes
# Out:
# country                          object
# happiness_score                 float64
# gdp_per_capita                  float64
# social_support                  float64
# life_expectancy                 float64
# freedom_to_make_life_choices    float64
# generosity                      float64
# perceptions_of_corruption       float64
# dtype: object

# %%
df9.head(1)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    71.15                         0.961      -0.019
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                      0.182                     1.778
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.888                         1.585
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.535
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.535                2.363

# %%
df9 = df9.drop(columns=[
                        'Standard error of ladder score',
                        'upperwhisker',
                        'lowerwhisker',
                        'Logged GDP per capita',
                        'Social support',
                        'Freedom to make life choices',
                        'Generosity',
                        'Ladder score in Dystopia',
                        'Explained by: Healthy life expectancy',
                        'Explained by: Perceptions of corruption',
                        'Dystopia + residual'],axis=1)

# %%
df9.head(1)
# Out:
#   Country name  Ladder score  Healthy life expectancy  \
# 0      Finland         7.804                    71.15
#
#    Perceptions of corruption  Explained by: Log GDP per capita  \
# 0                      0.182                             1.888
#
#    Explained by: Social support  Explained by: Freedom to make life choices  \
# 0                         1.585                                       0.772
#
#    Explained by: Generosity
# 0                     0.126

# %%
#Rename the columns for consistency
df9 = df9.rename({
    'Country name':'country',
    'Ladder score':'happiness_score',
    'Explained by: Log GDP per capita':'gdp_per_capita',
    'Explained by: Social support':'social_support',
    'Healthy life expectancy':'life_expectancy',
    'Explained by: Freedom to make life choices':'freedom_to_make_life_choices',
    'Explained by: Generosity':'generosity',
    'Perceptions of corruption':'perceptions_of_corruption'
    }, axis =1)
df9.head()
# Out:
#        country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0      Finland            7.804           71.150                      0.182
# 1      Denmark            7.586           71.250                      0.196
# 2      Iceland            7.530           72.050                      0.668
# 3       Israel            7.473           72.697                      0.708
# 4  Netherlands            7.403           71.550                      0.379
#
#    gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0           1.888           1.585                         0.772       0.126
# 1           1.949           1.548                         0.734       0.208
# 2           1.926           1.620                         0.738       0.250
# 3           1.833           1.521                         0.569       0.124
# 4           1.942           1.488                         0.672       0.251

# %%
df9.dtypes
# Out:
# country                          object
# happiness_score                 float64
# life_expectancy                 float64
# perceptions_of_corruption       float64
# gdp_per_capita                  float64
# social_support                  float64
# freedom_to_make_life_choices    float64
# generosity                      float64
# dtype: object

# %% [markdown]
# # Cleaning the data to keep the common countries data in years 2015, 2022 and 2023

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df8['country']) &
    df1['country'].isin(df9['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df8 = df8[df8['country'].isin(df1['country'])]
df9 = df9[df9['country'].isin(df1['country'])]

# %%
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 11 columns]

# %%
df8
# Out:
#           country  happiness_score  gdp_per_capita  social_support  \
# 0         Finland            7.821           1.892           1.258
# 1         Denmark            7.636           1.953           1.243
# 2         Iceland            7.557           1.936           1.320
# 3     Switzerland            7.512           2.026           1.226
# 4     Netherlands            7.415           1.945           1.206
# ..            ...              ...             ...             ...
# 138      Tanzania            3.702           0.848           0.597
# 139  Sierra Leone            3.574           0.686           0.416
# 143      Zimbabwe            2.995           0.947           0.690
# 144       Lebanon            2.955           1.392           0.498
# 145   Afghanistan            2.404           0.758           0.000
#
#      life_expectancy  freedom_to_make_life_choices  generosity  \
# 0              0.775                         0.736       0.109
# 1              0.777                         0.719       0.188
# 2              0.803                         0.718       0.270
# 3              0.822                         0.677       0.147
# 4              0.787                         0.651       0.271
# ..               ...                           ...         ...
# 138            0.425                         0.578       0.248
# 139            0.273                         0.387       0.202
# 143            0.270                         0.329       0.106
# 144            0.631                         0.103       0.082
# 145            0.289                         0.000       0.089
#
#      perceptions_of_corruption
# 0                        0.534
# 1                        0.532
# 2                        0.191
# 3                        0.461
# 4                        0.419
# ..                         ...
# 138                      0.270
# 139                      0.055
# 143                      0.105
# 144                      0.034
# 145                      0.005
#
# [113 rows x 8 columns]

# %%
df9
# Out:
#           country  happiness_score  life_expectancy  \
# 0         Finland            7.804           71.150
# 1         Denmark            7.586           71.250
# 2         Iceland            7.530           72.050
# 3          Israel            7.473           72.697
# 4     Netherlands            7.403           71.550
# ..            ...              ...              ...
# 130        Malawi            3.495           58.475
# 133      Zimbabwe            3.204           54.050
# 134  Sierra Leone            3.138           54.900
# 135       Lebanon            2.392           66.149
# 136   Afghanistan            1.859           54.712
#
#      perceptions_of_corruption  gdp_per_capita  social_support  \
# 0                        0.182           1.888           1.585
# 1                        0.196           1.949           1.548
# 2                        0.668           1.926           1.620
# 3                        0.708           1.833           1.521
# 4                        0.379           1.942           1.488
# ..                         ...             ...             ...
# 130                      0.749           0.637           0.479
# 133                      0.766           0.758           0.881
# 134                      0.858           0.670           0.540
# 135                      0.891           1.417           0.476
# 136                      0.847           0.645           0.000
#
#      freedom_to_make_life_choices  generosity
# 0                           0.772       0.126
# 1                           0.734       0.208
# 2                           0.738       0.250
# 3                           0.569       0.124
# 4                           0.672       0.251
# ..                            ...         ...
# 130                         0.490       0.139
# 133                         0.363       0.112
# 134                         0.371       0.193
# 135                         0.123       0.061
# 136                         0.000       0.093
#
# [113 rows x 8 columns]

# %%
duplicate_rows = df8[df8.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [country, happiness_score, gdp_per_capita, social_support, life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption]
# Index: []

# %%
duplicate_rows = df9[df9.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [country, happiness_score, life_expectancy, perceptions_of_corruption, gdp_per_capita, social_support, freedom_to_make_life_choices, generosity]
# Index: []

# %% [markdown]
# # Cleaning the data to keep the common countries data in years 2015, 2020 and 2021

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df2['country']) &
    df1['country'].isin(df3['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df2 = df2[df2['country'].isin(df1['country'])]
df3 = df3[df3['country'].isin(df1['country'])]

# %%
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 11 columns]

# %%
df2
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Denmark  Europe     Northern Europe       DNK            7.526
# 1    Switzerland  Europe      Western Europe       CHE            7.509
# 2        Iceland  Europe     Northern Europe       ISL            7.501
# 3         Norway  Europe     Northern Europe       NOR            7.498
# 4        Finland  Europe     Northern Europe       FIN            7.413
# ..           ...     ...                 ...       ...              ...
# 130     Tanzania  Africa  Sub-Saharan Africa       TZA            3.666
# 132       Guinea  Africa  Sub-Saharan Africa       GIN            3.607
# 134        Benin  Africa  Sub-Saharan Africa       BEN            3.484
# 135  Afghanistan    Asia       Southern Asia       AFG            3.360
# 136         Togo  Africa  Sub-Saharan Africa       TGO            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.44178         1.16374          0.79504
# 1           1.52733         1.14524          0.86303
# 2           1.42666         1.18326          0.86733
# 3           1.57744         1.12690          0.79579
# 4           1.40598         1.13464          0.81091
# ..              ...             ...              ...
# 130         0.47155         0.77623          0.35700
# 132         0.22415         0.31090          0.18829
# 134         0.39499         0.10419          0.21028
# 135         0.38227         0.11037          0.17344
# 136         0.28123         0.00000          0.24811
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.57941     0.36171                    0.44453
# 1                         0.58557     0.28083                    0.41203
# 2                         0.56624     0.47678                    0.14975
# 3                         0.59609     0.37895                    0.35776
# 4                         0.57104     0.25492                    0.41004
# ..                            ...         ...                        ...
# 130                       0.31760     0.31472                    0.05099
# 132                       0.30953     0.29914                    0.11920
# 134                       0.39747     0.20180                    0.06681
# 135                       0.16430     0.31268                    0.07112
# 136                       0.34678     0.17517                    0.11587
#
# [113 rows x 11 columns]

# %%
df3
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0         Norway  Europe     Northern Europe       NOR            7.537
# 1        Denmark  Europe     Northern Europe       DNK            7.522
# 2        Iceland  Europe     Northern Europe       ISL            7.504
# 3    Switzerland  Europe      Western Europe       CHE            7.494
# 4        Finland  Europe     Northern Europe       FIN            7.469
# ..           ...     ...                 ...       ...              ...
# 126  Afghanistan    Asia       Southern Asia       AFG            3.794
# 128        Benin  Africa  Sub-Saharan Africa       BEN            3.657
# 133       Guinea  Africa  Sub-Saharan Africa       GIN            3.507
# 134         Togo  Africa  Sub-Saharan Africa       TGO            3.495
# 137     Tanzania  Africa  Sub-Saharan Africa       TZA            3.349
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.616463        1.533524         0.796667
# 1          1.482383        1.551122         0.792566
# 2          1.480633        1.610574         0.833552
# 3          1.564980        1.516912         0.858131
# 4          1.443572        1.540247         0.809158
# ..              ...             ...              ...
# 126        0.401477        0.581543         0.180747
# 128        0.431085        0.435300         0.209930
# 133        0.244550        0.791245         0.194129
# 134        0.305445        0.431883         0.247106
# 137        0.511136        1.041990         0.364509
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                        0.635423    0.362012                   0.315964
# 1                        0.626007    0.355280                   0.400770
# 2                        0.627163    0.475540                   0.153527
# 3                        0.620071    0.290549                   0.367007
# 4                        0.617951    0.245483                   0.382612
# ..                            ...         ...                        ...
# 126                      0.106180    0.311871                   0.061158
# 128                      0.425963    0.207948                   0.060929
# 133                      0.348588    0.264815                   0.110938
# 134                      0.380426    0.196896                   0.095665
# 137                      0.390018    0.354256                   0.066035
#
# [113 rows x 11 columns]

# %% [markdown]
# # rechecking the data to keep the common countries data in all Years

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df4['country']) &
    df1['country'].isin(df5['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df4 = df4[df4['country'].isin(df1['country'])]
df5 = df5[df5['country'].isin(df1['country'])]

# %%
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 11 columns]

# %%
df4
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.632           1.305
# 1                 2       Norway            7.594           1.456
# 2                 3      Denmark            7.555           1.351
# 3                 4      Iceland            7.495           1.343
# 4                 5  Switzerland            7.487           1.420
# ..              ...          ...              ...             ...
# 139             140       Guinea            3.964           0.344
# 143             144     Zimbabwe            3.692           0.357
# 144             145  Afghanistan            3.632           0.332
# 146             147       Malawi            3.587           0.186
# 152             153     Tanzania            3.303           0.455
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.592            0.874                         0.681
# 1             1.582            0.861                         0.686
# 2             1.590            0.868                         0.683
# 3             1.644            0.914                         0.677
# 4             1.549            0.927                         0.660
# ..              ...              ...                           ...
# 139           0.792            0.211                         0.394
# 143           1.094            0.248                         0.406
# 144           0.537            0.255                         0.085
# 146           0.541            0.306                         0.531
# 152           0.991            0.381                         0.481
#
#      generosity  perceptions_of_corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 139       0.185                      0.094
# 143       0.132                      0.099
# 144       0.191                      0.036
# 146       0.210                      0.080
# 152       0.270                      0.097
#
# [113 rows x 9 columns]

# %%
df5
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.769           1.340
# 1                 2      Denmark            7.600           1.383
# 2                 3       Norway            7.554           1.488
# 3                 4      Iceland            7.494           1.380
# 4                 5  Netherlands            7.488           1.396
# ..              ...          ...              ...             ...
# 139             140        India            4.015           0.755
# 145             146     Zimbabwe            3.663           0.366
# 149             150       Malawi            3.410           0.191
# 152             153     Tanzania            3.231           0.476
# 153             154  Afghanistan            3.203           0.350
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.587            0.986                         0.596
# 1             1.573            0.996                         0.592
# 2             1.582            1.028                         0.603
# 3             1.624            1.026                         0.591
# 4             1.522            0.999                         0.557
# ..              ...              ...                           ...
# 139           0.765            0.588                         0.498
# 145           1.114            0.433                         0.361
# 149           0.560            0.495                         0.443
# 152           0.885            0.499                         0.417
# 153           0.517            0.361                         0.000
#
#      generosity  perceptions_of_corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 139       0.200                      0.085
# 145       0.151                      0.089
# 149       0.218                      0.089
# 152       0.276                      0.147
# 153       0.158                      0.025
#
# [113 rows x 9 columns]

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df6['country']) &
    df1['country'].isin(df7['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df6 = df6[df6['country'].isin(df1['country'])]
df7 = df7[df7['country'].isin(df1['country'])]

# %%
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 11 columns]

# %%
df6
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland           7.8087        71.900825                   0.195445
# 1        Denmark           7.6456        72.402504                   0.168489
# 2    Switzerland           7.5599        74.102448                   0.303728
# 3        Iceland           7.5045        73.000000                   0.711710
# 4         Norway           7.4880        73.200783                   0.263218
# ..           ...              ...              ...                        ...
# 143        India           3.5733        60.215187                   0.772043
# 144       Malawi           3.5380        57.592888                   0.731701
# 147     Tanzania           3.4762        57.496075                   0.619799
# 150     Zimbabwe           3.2992        55.617260                   0.810237
# 152  Afghanistan           2.5669        52.590000                   0.933687
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0          1.285190        1.499526                      0.662317    0.159670
# 1          1.326949        1.503449                      0.665040    0.242793
# 2          1.390774        1.472403                      0.628954    0.269056
# 3          1.326502        1.547567                      0.661981    0.362330
# 4          1.424207        1.495173                      0.670201    0.287985
# ..              ...             ...                           ...         ...
# 143        0.730576        0.644199                      0.581142    0.237072
# 144        0.176535        0.530368                      0.487390    0.213185
# 147        0.457163        0.872675                      0.509343    0.271541
# 150        0.425564        1.047835                      0.377405    0.151349
# 152        0.300706        0.356434                      0.000000    0.135235
#
# [113 rows x 8 columns]

# %%
df7
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland            7.842           72.000                      0.186
# 1        Denmark            7.620           72.700                      0.179
# 2    Switzerland            7.571           74.400                      0.292
# 3        Iceland            7.554           73.000                      0.673
# 4    Netherlands            7.464           72.400                      0.338
# ..           ...              ...              ...                        ...
# 138        India            3.819           60.633                      0.774
# 141     Tanzania            3.623           57.999                      0.577
# 143       Malawi            3.600           57.948                      0.729
# 147     Zimbabwe            3.145           56.201                      0.821
# 148  Afghanistan            2.523           52.493                      0.924
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity
# 0             1.446           1.106                         0.691       0.124
# 1             1.502           1.108                         0.686       0.208
# 2             1.566           1.079                         0.653       0.204
# 3             1.482           1.172                         0.698       0.293
# 4             1.501           1.079                         0.647       0.302
# ..              ...             ...                           ...         ...
# 138           0.741           0.316                         0.622       0.246
# 141           0.433           0.540                         0.549       0.307
# 143           0.113           0.168                         0.484       0.213
# 147           0.457           0.649                         0.359       0.157
# 148           0.370           0.000                         0.000       0.122
#
# [113 rows x 8 columns]

# %%
# Find common country names among three dataframes
common_countries_mask = (
    df1['country'].isin(df8['country']) &
    df1['country'].isin(df9['country'])
)

# Keep only the rows with common country names
df1 = df1[common_countries_mask]
df8 = df8[df8['country'].isin(df1['country'])]
df9 = df9[df9['country'].isin(df1['country'])]

# %%
df8
# Out:
#           country  happiness_score  gdp_per_capita  social_support  \
# 0         Finland            7.821           1.892           1.258
# 1         Denmark            7.636           1.953           1.243
# 2         Iceland            7.557           1.936           1.320
# 3     Switzerland            7.512           2.026           1.226
# 4     Netherlands            7.415           1.945           1.206
# ..            ...              ...             ...             ...
# 138      Tanzania            3.702           0.848           0.597
# 139  Sierra Leone            3.574           0.686           0.416
# 143      Zimbabwe            2.995           0.947           0.690
# 144       Lebanon            2.955           1.392           0.498
# 145   Afghanistan            2.404           0.758           0.000
#
#      life_expectancy  freedom_to_make_life_choices  generosity  \
# 0              0.775                         0.736       0.109
# 1              0.777                         0.719       0.188
# 2              0.803                         0.718       0.270
# 3              0.822                         0.677       0.147
# 4              0.787                         0.651       0.271
# ..               ...                           ...         ...
# 138            0.425                         0.578       0.248
# 139            0.273                         0.387       0.202
# 143            0.270                         0.329       0.106
# 144            0.631                         0.103       0.082
# 145            0.289                         0.000       0.089
#
#      perceptions_of_corruption
# 0                        0.534
# 1                        0.532
# 2                        0.191
# 3                        0.461
# 4                        0.419
# ..                         ...
# 138                      0.270
# 139                      0.055
# 143                      0.105
# 144                      0.034
# 145                      0.005
#
# [113 rows x 8 columns]

# %%
df9
# Out:
#           country  happiness_score  life_expectancy  \
# 0         Finland            7.804           71.150
# 1         Denmark            7.586           71.250
# 2         Iceland            7.530           72.050
# 3          Israel            7.473           72.697
# 4     Netherlands            7.403           71.550
# ..            ...              ...              ...
# 130        Malawi            3.495           58.475
# 133      Zimbabwe            3.204           54.050
# 134  Sierra Leone            3.138           54.900
# 135       Lebanon            2.392           66.149
# 136   Afghanistan            1.859           54.712
#
#      perceptions_of_corruption  gdp_per_capita  social_support  \
# 0                        0.182           1.888           1.585
# 1                        0.196           1.949           1.548
# 2                        0.668           1.926           1.620
# 3                        0.708           1.833           1.521
# 4                        0.379           1.942           1.488
# ..                         ...             ...             ...
# 130                      0.749           0.637           0.479
# 133                      0.766           0.758           0.881
# 134                      0.858           0.670           0.540
# 135                      0.891           1.417           0.476
# 136                      0.847           0.645           0.000
#
#      freedom_to_make_life_choices  generosity
# 0                           0.772       0.126
# 1                           0.734       0.208
# 2                           0.738       0.250
# 3                           0.569       0.124
# 4                           0.672       0.251
# ..                            ...         ...
# 130                         0.490       0.139
# 133                         0.363       0.112
# 134                         0.371       0.193
# 135                         0.123       0.061
# 136                         0.000       0.093
#
# [113 rows x 8 columns]

# %% [markdown]
# # mapping continents Data with all the years dataframes

# %%
mapping_country = pd.read_csv("./resources/continents2.csv")

# %%
mapping_country.head(1)
# Out:
#           name alpha-2 alpha-3  country-code     iso_3166-2 region  \
# 0  Afghanistan      AF     AFG             4  ISO 3166-2:AF   Asia
#
#       sub-region intermediate-region  region-code  sub-region-code  \
# 0  Southern Asia                 NaN        142.0             34.0
#
#    intermediate-region-code
# 0                       NaN

# %%
# Dropping irrelevant columns
mapping_country.drop('alpha-2', inplace=True, axis=1)
# Remove all columns between column name 'country-code' to 'iso_3166-2' 
mapping_country = mapping_country.drop(mapping_country.loc[:, 'country-code':'iso_3166-2'].columns, axis=1)
# Remove all columns between column name 'intermediate-region' to 'intermediate-region-code' 
mapping_country = mapping_country.drop(mapping_country.loc[:, 'intermediate-region':'intermediate-region-code'].columns, axis=1)
mapping_country.head(1)
# Out:
#           name alpha-3 region     sub-region
# 0  Afghanistan     AFG   Asia  Southern Asia

# %%
#Rename the columns for consistency
mapping_country = mapping_country.rename({'name':'country','alpha-3':'iso_alpha','sub-region':'sub_region'}, axis =1)
mapping_country.head(1)
# Out:
#        country iso_alpha region     sub_region
# 0  Afghanistan       AFG   Asia  Southern Asia

# %%
df_2018 = df4.merge(mapping_country, on='country', how='left')

df_2018
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.632           1.305
# 1                 2       Norway            7.594           1.456
# 2                 3      Denmark            7.555           1.351
# 3                 4      Iceland            7.495           1.343
# 4                 5  Switzerland            7.487           1.420
# ..              ...          ...              ...             ...
# 108             140       Guinea            3.964           0.344
# 109             144     Zimbabwe            3.692           0.357
# 110             145  Afghanistan            3.632           0.332
# 111             147       Malawi            3.587           0.186
# 112             153     Tanzania            3.303           0.455
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.592            0.874                         0.681
# 1             1.582            0.861                         0.686
# 2             1.590            0.868                         0.683
# 3             1.644            0.914                         0.677
# 4             1.549            0.927                         0.660
# ..              ...              ...                           ...
# 108           0.792            0.211                         0.394
# 109           1.094            0.248                         0.406
# 110           0.537            0.255                         0.085
# 111           0.541            0.306                         0.531
# 112           0.991            0.381                         0.481
#
#      generosity  perceptions_of_corruption iso_alpha  region  \
# 0         0.202                      0.393       FIN  Europe
# 1         0.286                      0.340       NOR  Europe
# 2         0.284                      0.408       DNK  Europe
# 3         0.353                      0.138       ISL  Europe
# 4         0.256                      0.357       CHE  Europe
# ..          ...                        ...       ...     ...
# 108       0.185                      0.094       GIN  Africa
# 109       0.132                      0.099       ZWE  Africa
# 110       0.191                      0.036       AFG    Asia
# 111       0.210                      0.080       MWI  Africa
# 112       0.270                      0.097       TZA  Africa
#
#              sub_region
# 0       Northern Europe
# 1       Northern Europe
# 2       Northern Europe
# 3       Northern Europe
# 4        Western Europe
# ..                  ...
# 108  Sub-Saharan Africa
# 109  Sub-Saharan Africa
# 110       Southern Asia
# 111  Sub-Saharan Africa
# 112  Sub-Saharan Africa
#
# [113 rows x 12 columns]

# %%
df_2018.isnull().sum()
# Out:
# happiness_rank                  0
# country                         0
# happiness_score                 0
# gdp_per_capita                  0
# social_support                  0
# life_expectancy                 0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       1
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2018.fillna(0.35, inplace=True)

# %%
df_2018.isnull().sum()
# Out:
# happiness_rank                  0
# country                         0
# happiness_score                 0
# gdp_per_capita                  0
# social_support                  0
# life_expectancy                 0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2019 = df5.merge(mapping_country, on='country', how='left')

df_2019
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.769           1.340
# 1                 2      Denmark            7.600           1.383
# 2                 3       Norway            7.554           1.488
# 3                 4      Iceland            7.494           1.380
# 4                 5  Netherlands            7.488           1.396
# ..              ...          ...              ...             ...
# 108             140        India            4.015           0.755
# 109             146     Zimbabwe            3.663           0.366
# 110             150       Malawi            3.410           0.191
# 111             153     Tanzania            3.231           0.476
# 112             154  Afghanistan            3.203           0.350
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.587            0.986                         0.596
# 1             1.573            0.996                         0.592
# 2             1.582            1.028                         0.603
# 3             1.624            1.026                         0.591
# 4             1.522            0.999                         0.557
# ..              ...              ...                           ...
# 108           0.765            0.588                         0.498
# 109           1.114            0.433                         0.361
# 110           0.560            0.495                         0.443
# 111           0.885            0.499                         0.417
# 112           0.517            0.361                         0.000
#
#      generosity  perceptions_of_corruption iso_alpha  region  \
# 0         0.153                      0.393       FIN  Europe
# 1         0.252                      0.410       DNK  Europe
# 2         0.271                      0.341       NOR  Europe
# 3         0.354                      0.118       ISL  Europe
# 4         0.322                      0.298       NLD  Europe
# ..          ...                        ...       ...     ...
# 108       0.200                      0.085       IND    Asia
# 109       0.151                      0.089       ZWE  Africa
# 110       0.218                      0.089       MWI  Africa
# 111       0.276                      0.147       TZA  Africa
# 112       0.158                      0.025       AFG    Asia
#
#              sub_region
# 0       Northern Europe
# 1       Northern Europe
# 2       Northern Europe
# 3       Northern Europe
# 4        Western Europe
# ..                  ...
# 108       Southern Asia
# 109  Sub-Saharan Africa
# 110  Sub-Saharan Africa
# 111  Sub-Saharan Africa
# 112       Southern Asia
#
# [113 rows x 12 columns]

# %%
df_2019.isnull().sum()
# Out:
# happiness_rank                  0
# country                         0
# happiness_score                 0
# gdp_per_capita                  0
# social_support                  0
# life_expectancy                 0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2020 = df6.merge(mapping_country, on='country', how='left')

df_2020
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland           7.8087        71.900825                   0.195445
# 1        Denmark           7.6456        72.402504                   0.168489
# 2    Switzerland           7.5599        74.102448                   0.303728
# 3        Iceland           7.5045        73.000000                   0.711710
# 4         Norway           7.4880        73.200783                   0.263218
# ..           ...              ...              ...                        ...
# 108        India           3.5733        60.215187                   0.772043
# 109       Malawi           3.5380        57.592888                   0.731701
# 110     Tanzania           3.4762        57.496075                   0.619799
# 111     Zimbabwe           3.2992        55.617260                   0.810237
# 112  Afghanistan           2.5669        52.590000                   0.933687
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity  \
# 0          1.285190        1.499526                      0.662317    0.159670
# 1          1.326949        1.503449                      0.665040    0.242793
# 2          1.390774        1.472403                      0.628954    0.269056
# 3          1.326502        1.547567                      0.661981    0.362330
# 4          1.424207        1.495173                      0.670201    0.287985
# ..              ...             ...                           ...         ...
# 108        0.730576        0.644199                      0.581142    0.237072
# 109        0.176535        0.530368                      0.487390    0.213185
# 110        0.457163        0.872675                      0.509343    0.271541
# 111        0.425564        1.047835                      0.377405    0.151349
# 112        0.300706        0.356434                      0.000000    0.135235
#
#     iso_alpha  region          sub_region
# 0         FIN  Europe     Northern Europe
# 1         DNK  Europe     Northern Europe
# 2         CHE  Europe      Western Europe
# 3         ISL  Europe     Northern Europe
# 4         NOR  Europe     Northern Europe
# ..        ...     ...                 ...
# 108       IND    Asia       Southern Asia
# 109       MWI  Africa  Sub-Saharan Africa
# 110       TZA  Africa  Sub-Saharan Africa
# 111       ZWE  Africa  Sub-Saharan Africa
# 112       AFG    Asia       Southern Asia
#
# [113 rows x 11 columns]

# %%
df_2020.isnull().sum()
# Out:
# country                         0
# happiness_score                 0
# life_expectancy                 0
# perceptions_of_corruption       0
# gdp_per_capita                  0
# social_support                  0
# freedom_to_make_life_choices    0
# generosity                      0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2021 = df7.merge(mapping_country, on='country', how='left')

df_2021
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland            7.842           72.000                      0.186
# 1        Denmark            7.620           72.700                      0.179
# 2    Switzerland            7.571           74.400                      0.292
# 3        Iceland            7.554           73.000                      0.673
# 4    Netherlands            7.464           72.400                      0.338
# ..           ...              ...              ...                        ...
# 108        India            3.819           60.633                      0.774
# 109     Tanzania            3.623           57.999                      0.577
# 110       Malawi            3.600           57.948                      0.729
# 111     Zimbabwe            3.145           56.201                      0.821
# 112  Afghanistan            2.523           52.493                      0.924
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity  \
# 0             1.446           1.106                         0.691       0.124
# 1             1.502           1.108                         0.686       0.208
# 2             1.566           1.079                         0.653       0.204
# 3             1.482           1.172                         0.698       0.293
# 4             1.501           1.079                         0.647       0.302
# ..              ...             ...                           ...         ...
# 108           0.741           0.316                         0.622       0.246
# 109           0.433           0.540                         0.549       0.307
# 110           0.113           0.168                         0.484       0.213
# 111           0.457           0.649                         0.359       0.157
# 112           0.370           0.000                         0.000       0.122
#
#     iso_alpha  region          sub_region
# 0         FIN  Europe     Northern Europe
# 1         DNK  Europe     Northern Europe
# 2         CHE  Europe      Western Europe
# 3         ISL  Europe     Northern Europe
# 4         NLD  Europe      Western Europe
# ..        ...     ...                 ...
# 108       IND    Asia       Southern Asia
# 109       TZA  Africa  Sub-Saharan Africa
# 110       MWI  Africa  Sub-Saharan Africa
# 111       ZWE  Africa  Sub-Saharan Africa
# 112       AFG    Asia       Southern Asia
#
# [113 rows x 11 columns]

# %%
df_2021.isnull().sum()
# Out:
# country                         0
# happiness_score                 0
# life_expectancy                 0
# perceptions_of_corruption       0
# gdp_per_capita                  0
# social_support                  0
# freedom_to_make_life_choices    0
# generosity                      0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2022 = df8.merge(mapping_country, on='country', how='left')

df_2022
# Out:
#           country  happiness_score  gdp_per_capita  social_support  \
# 0         Finland            7.821           1.892           1.258
# 1         Denmark            7.636           1.953           1.243
# 2         Iceland            7.557           1.936           1.320
# 3     Switzerland            7.512           2.026           1.226
# 4     Netherlands            7.415           1.945           1.206
# ..            ...              ...             ...             ...
# 108      Tanzania            3.702           0.848           0.597
# 109  Sierra Leone            3.574           0.686           0.416
# 110      Zimbabwe            2.995           0.947           0.690
# 111       Lebanon            2.955           1.392           0.498
# 112   Afghanistan            2.404           0.758           0.000
#
#      life_expectancy  freedom_to_make_life_choices  generosity  \
# 0              0.775                         0.736       0.109
# 1              0.777                         0.719       0.188
# 2              0.803                         0.718       0.270
# 3              0.822                         0.677       0.147
# 4              0.787                         0.651       0.271
# ..               ...                           ...         ...
# 108            0.425                         0.578       0.248
# 109            0.273                         0.387       0.202
# 110            0.270                         0.329       0.106
# 111            0.631                         0.103       0.082
# 112            0.289                         0.000       0.089
#
#      perceptions_of_corruption iso_alpha  region          sub_region
# 0                        0.534       FIN  Europe     Northern Europe
# 1                        0.532       DNK  Europe     Northern Europe
# 2                        0.191       ISL  Europe     Northern Europe
# 3                        0.461       CHE  Europe      Western Europe
# 4                        0.419       NLD  Europe      Western Europe
# ..                         ...       ...     ...                 ...
# 108                      0.270       TZA  Africa  Sub-Saharan Africa
# 109                      0.055       SLE  Africa  Sub-Saharan Africa
# 110                      0.105       ZWE  Africa  Sub-Saharan Africa
# 111                      0.034       LBN    Asia        Western Asia
# 112                      0.005       AFG    Asia       Southern Asia
#
# [113 rows x 11 columns]

# %%
df_2022.isnull().sum()
# Out:
# country                         0
# happiness_score                 0
# gdp_per_capita                  0
# social_support                  0
# life_expectancy                 0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df_2023 = df9.merge(mapping_country, on='country', how='left')

df_2023
# Out:
#           country  happiness_score  life_expectancy  \
# 0         Finland            7.804           71.150
# 1         Denmark            7.586           71.250
# 2         Iceland            7.530           72.050
# 3          Israel            7.473           72.697
# 4     Netherlands            7.403           71.550
# ..            ...              ...              ...
# 108        Malawi            3.495           58.475
# 109      Zimbabwe            3.204           54.050
# 110  Sierra Leone            3.138           54.900
# 111       Lebanon            2.392           66.149
# 112   Afghanistan            1.859           54.712
#
#      perceptions_of_corruption  gdp_per_capita  social_support  \
# 0                        0.182           1.888           1.585
# 1                        0.196           1.949           1.548
# 2                        0.668           1.926           1.620
# 3                        0.708           1.833           1.521
# 4                        0.379           1.942           1.488
# ..                         ...             ...             ...
# 108                      0.749           0.637           0.479
# 109                      0.766           0.758           0.881
# 110                      0.858           0.670           0.540
# 111                      0.891           1.417           0.476
# 112                      0.847           0.645           0.000
#
#      freedom_to_make_life_choices  generosity iso_alpha  region  \
# 0                           0.772       0.126       FIN  Europe
# 1                           0.734       0.208       DNK  Europe
# 2                           0.738       0.250       ISL  Europe
# 3                           0.569       0.124       ISR    Asia
# 4                           0.672       0.251       NLD  Europe
# ..                            ...         ...       ...     ...
# 108                         0.490       0.139       MWI  Africa
# 109                         0.363       0.112       ZWE  Africa
# 110                         0.371       0.193       SLE  Africa
# 111                         0.123       0.061       LBN    Asia
# 112                         0.000       0.093       AFG    Asia
#
#              sub_region
# 0       Northern Europe
# 1       Northern Europe
# 2       Northern Europe
# 3          Western Asia
# 4        Western Europe
# ..                  ...
# 108  Sub-Saharan Africa
# 109  Sub-Saharan Africa
# 110  Sub-Saharan Africa
# 111        Western Asia
# 112       Southern Asia
#
# [113 rows x 11 columns]

# %%
df_2023.isnull().sum()
# Out:
# country                         0
# happiness_score                 0
# life_expectancy                 0
# perceptions_of_corruption       0
# gdp_per_capita                  0
# social_support                  0
# freedom_to_make_life_choices    0
# generosity                      0
# iso_alpha                       0
# region                          0
# sub_region                      0
# dtype: int64

# %%
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 11 columns]

# %%
df2
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Denmark  Europe     Northern Europe       DNK            7.526
# 1    Switzerland  Europe      Western Europe       CHE            7.509
# 2        Iceland  Europe     Northern Europe       ISL            7.501
# 3         Norway  Europe     Northern Europe       NOR            7.498
# 4        Finland  Europe     Northern Europe       FIN            7.413
# ..           ...     ...                 ...       ...              ...
# 130     Tanzania  Africa  Sub-Saharan Africa       TZA            3.666
# 132       Guinea  Africa  Sub-Saharan Africa       GIN            3.607
# 134        Benin  Africa  Sub-Saharan Africa       BEN            3.484
# 135  Afghanistan    Asia       Southern Asia       AFG            3.360
# 136         Togo  Africa  Sub-Saharan Africa       TGO            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.44178         1.16374          0.79504
# 1           1.52733         1.14524          0.86303
# 2           1.42666         1.18326          0.86733
# 3           1.57744         1.12690          0.79579
# 4           1.40598         1.13464          0.81091
# ..              ...             ...              ...
# 130         0.47155         0.77623          0.35700
# 132         0.22415         0.31090          0.18829
# 134         0.39499         0.10419          0.21028
# 135         0.38227         0.11037          0.17344
# 136         0.28123         0.00000          0.24811
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.57941     0.36171                    0.44453
# 1                         0.58557     0.28083                    0.41203
# 2                         0.56624     0.47678                    0.14975
# 3                         0.59609     0.37895                    0.35776
# 4                         0.57104     0.25492                    0.41004
# ..                            ...         ...                        ...
# 130                       0.31760     0.31472                    0.05099
# 132                       0.30953     0.29914                    0.11920
# 134                       0.39747     0.20180                    0.06681
# 135                       0.16430     0.31268                    0.07112
# 136                       0.34678     0.17517                    0.11587
#
# [113 rows x 11 columns]

# %%
df3
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0         Norway  Europe     Northern Europe       NOR            7.537
# 1        Denmark  Europe     Northern Europe       DNK            7.522
# 2        Iceland  Europe     Northern Europe       ISL            7.504
# 3    Switzerland  Europe      Western Europe       CHE            7.494
# 4        Finland  Europe     Northern Europe       FIN            7.469
# ..           ...     ...                 ...       ...              ...
# 126  Afghanistan    Asia       Southern Asia       AFG            3.794
# 128        Benin  Africa  Sub-Saharan Africa       BEN            3.657
# 133       Guinea  Africa  Sub-Saharan Africa       GIN            3.507
# 134         Togo  Africa  Sub-Saharan Africa       TGO            3.495
# 137     Tanzania  Africa  Sub-Saharan Africa       TZA            3.349
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.616463        1.533524         0.796667
# 1          1.482383        1.551122         0.792566
# 2          1.480633        1.610574         0.833552
# 3          1.564980        1.516912         0.858131
# 4          1.443572        1.540247         0.809158
# ..              ...             ...              ...
# 126        0.401477        0.581543         0.180747
# 128        0.431085        0.435300         0.209930
# 133        0.244550        0.791245         0.194129
# 134        0.305445        0.431883         0.247106
# 137        0.511136        1.041990         0.364509
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                        0.635423    0.362012                   0.315964
# 1                        0.626007    0.355280                   0.400770
# 2                        0.627163    0.475540                   0.153527
# 3                        0.620071    0.290549                   0.367007
# 4                        0.617951    0.245483                   0.382612
# ..                            ...         ...                        ...
# 126                      0.106180    0.311871                   0.061158
# 128                      0.425963    0.207948                   0.060929
# 133                      0.348588    0.264815                   0.110938
# 134                      0.380426    0.196896                   0.095665
# 137                      0.390018    0.354256                   0.066035
#
# [113 rows x 11 columns]

# %%
df_2018
# Out:
#      happiness_rank      country  happiness_score  gdp_per_capita  \
# 0                 1      Finland            7.632           1.305
# 1                 2       Norway            7.594           1.456
# 2                 3      Denmark            7.555           1.351
# 3                 4      Iceland            7.495           1.343
# 4                 5  Switzerland            7.487           1.420
# ..              ...          ...              ...             ...
# 108             140       Guinea            3.964           0.344
# 109             144     Zimbabwe            3.692           0.357
# 110             145  Afghanistan            3.632           0.332
# 111             147       Malawi            3.587           0.186
# 112             153     Tanzania            3.303           0.455
#
#      social_support  life_expectancy  freedom_to_make_life_choices  \
# 0             1.592            0.874                         0.681
# 1             1.582            0.861                         0.686
# 2             1.590            0.868                         0.683
# 3             1.644            0.914                         0.677
# 4             1.549            0.927                         0.660
# ..              ...              ...                           ...
# 108           0.792            0.211                         0.394
# 109           1.094            0.248                         0.406
# 110           0.537            0.255                         0.085
# 111           0.541            0.306                         0.531
# 112           0.991            0.381                         0.481
#
#      generosity  perceptions_of_corruption iso_alpha  region  \
# 0         0.202                      0.393       FIN  Europe
# 1         0.286                      0.340       NOR  Europe
# 2         0.284                      0.408       DNK  Europe
# 3         0.353                      0.138       ISL  Europe
# 4         0.256                      0.357       CHE  Europe
# ..          ...                        ...       ...     ...
# 108       0.185                      0.094       GIN  Africa
# 109       0.132                      0.099       ZWE  Africa
# 110       0.191                      0.036       AFG    Asia
# 111       0.210                      0.080       MWI  Africa
# 112       0.270                      0.097       TZA  Africa
#
#              sub_region
# 0       Northern Europe
# 1       Northern Europe
# 2       Northern Europe
# 3       Northern Europe
# 4        Western Europe
# ..                  ...
# 108  Sub-Saharan Africa
# 109  Sub-Saharan Africa
# 110       Southern Asia
# 111  Sub-Saharan Africa
# 112  Sub-Saharan Africa
#
# [113 rows x 12 columns]

# %%
df4=df_2018[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df4
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.632
# 1         Norway  Europe     Northern Europe       NOR            7.594
# 2        Denmark  Europe     Northern Europe       DNK            7.555
# 3        Iceland  Europe     Northern Europe       ISL            7.495
# 4    Switzerland  Europe      Western Europe       CHE            7.487
# ..           ...     ...                 ...       ...              ...
# 108       Guinea  Africa  Sub-Saharan Africa       GIN            3.964
# 109     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.692
# 110  Afghanistan    Asia       Southern Asia       AFG            3.632
# 111       Malawi  Africa  Sub-Saharan Africa       MWI            3.587
# 112     Tanzania  Africa  Sub-Saharan Africa       TZA            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.305           1.592            0.874
# 1             1.456           1.582            0.861
# 2             1.351           1.590            0.868
# 3             1.343           1.644            0.914
# 4             1.420           1.549            0.927
# ..              ...             ...              ...
# 108           0.344           0.792            0.211
# 109           0.357           1.094            0.248
# 110           0.332           0.537            0.255
# 111           0.186           0.541            0.306
# 112           0.455           0.991            0.381
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.681       0.202                      0.393
# 1                           0.686       0.286                      0.340
# 2                           0.683       0.284                      0.408
# 3                           0.677       0.353                      0.138
# 4                           0.660       0.256                      0.357
# ..                            ...         ...                        ...
# 108                         0.394       0.185                      0.094
# 109                         0.406       0.132                      0.099
# 110                         0.085       0.191                      0.036
# 111                         0.531       0.210                      0.080
# 112                         0.481       0.270                      0.097
#
# [113 rows x 11 columns]

# %%
df5 = df_2019.drop(columns=['happiness_rank'],axis=1)
df5
# Out:
#          country  happiness_score  gdp_per_capita  social_support  \
# 0        Finland            7.769           1.340           1.587
# 1        Denmark            7.600           1.383           1.573
# 2         Norway            7.554           1.488           1.582
# 3        Iceland            7.494           1.380           1.624
# 4    Netherlands            7.488           1.396           1.522
# ..           ...              ...             ...             ...
# 108        India            4.015           0.755           0.765
# 109     Zimbabwe            3.663           0.366           1.114
# 110       Malawi            3.410           0.191           0.560
# 111     Tanzania            3.231           0.476           0.885
# 112  Afghanistan            3.203           0.350           0.517
#
#      life_expectancy  freedom_to_make_life_choices  generosity  \
# 0              0.986                         0.596       0.153
# 1              0.996                         0.592       0.252
# 2              1.028                         0.603       0.271
# 3              1.026                         0.591       0.354
# 4              0.999                         0.557       0.322
# ..               ...                           ...         ...
# 108            0.588                         0.498       0.200
# 109            0.433                         0.361       0.151
# 110            0.495                         0.443       0.218
# 111            0.499                         0.417       0.276
# 112            0.361                         0.000       0.158
#
#      perceptions_of_corruption iso_alpha  region          sub_region
# 0                        0.393       FIN  Europe     Northern Europe
# 1                        0.410       DNK  Europe     Northern Europe
# 2                        0.341       NOR  Europe     Northern Europe
# 3                        0.118       ISL  Europe     Northern Europe
# 4                        0.298       NLD  Europe      Western Europe
# ..                         ...       ...     ...                 ...
# 108                      0.085       IND    Asia       Southern Asia
# 109                      0.089       ZWE  Africa  Sub-Saharan Africa
# 110                      0.089       MWI  Africa  Sub-Saharan Africa
# 111                      0.147       TZA  Africa  Sub-Saharan Africa
# 112                      0.025       AFG    Asia       Southern Asia
#
# [113 rows x 11 columns]

# %%
df5=df5[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df5
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.769
# 1        Denmark  Europe     Northern Europe       DNK            7.600
# 2         Norway  Europe     Northern Europe       NOR            7.554
# 3        Iceland  Europe     Northern Europe       ISL            7.494
# 4    Netherlands  Europe      Western Europe       NLD            7.488
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND            4.015
# 109     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.663
# 110       Malawi  Africa  Sub-Saharan Africa       MWI            3.410
# 111     Tanzania  Africa  Sub-Saharan Africa       TZA            3.231
# 112  Afghanistan    Asia       Southern Asia       AFG            3.203
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.340           1.587            0.986
# 1             1.383           1.573            0.996
# 2             1.488           1.582            1.028
# 3             1.380           1.624            1.026
# 4             1.396           1.522            0.999
# ..              ...             ...              ...
# 108           0.755           0.765            0.588
# 109           0.366           1.114            0.433
# 110           0.191           0.560            0.495
# 111           0.476           0.885            0.499
# 112           0.350           0.517            0.361
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 108                         0.498       0.200                      0.085
# 109                         0.361       0.151                      0.089
# 110                         0.443       0.218                      0.089
# 111                         0.417       0.276                      0.147
# 112                         0.000       0.158                      0.025
#
# [113 rows x 11 columns]

# %%
df_2020
# Out:
#          country  happiness_score  life_expectancy  perceptions_of_corruption  \
# 0        Finland           7.8087        71.900825                   0.195445
# 1        Denmark           7.6456        72.402504                   0.168489
# 2    Switzerland           7.5599        74.102448                   0.303728
# 3        Iceland           7.5045        73.000000                   0.711710
# 4         Norway           7.4880        73.200783                   0.263218
# ..           ...              ...              ...                        ...
# 108        India           3.5733        60.215187                   0.772043
# 109       Malawi           3.5380        57.592888                   0.731701
# 110     Tanzania           3.4762        57.496075                   0.619799
# 111     Zimbabwe           3.2992        55.617260                   0.810237
# 112  Afghanistan           2.5669        52.590000                   0.933687
#
#      gdp_per_capita  social_support  freedom_to_make_life_choices  generosity  \
# 0          1.285190        1.499526                      0.662317    0.159670
# 1          1.326949        1.503449                      0.665040    0.242793
# 2          1.390774        1.472403                      0.628954    0.269056
# 3          1.326502        1.547567                      0.661981    0.362330
# 4          1.424207        1.495173                      0.670201    0.287985
# ..              ...             ...                           ...         ...
# 108        0.730576        0.644199                      0.581142    0.237072
# 109        0.176535        0.530368                      0.487390    0.213185
# 110        0.457163        0.872675                      0.509343    0.271541
# 111        0.425564        1.047835                      0.377405    0.151349
# 112        0.300706        0.356434                      0.000000    0.135235
#
#     iso_alpha  region          sub_region
# 0         FIN  Europe     Northern Europe
# 1         DNK  Europe     Northern Europe
# 2         CHE  Europe      Western Europe
# 3         ISL  Europe     Northern Europe
# 4         NOR  Europe     Northern Europe
# ..        ...     ...                 ...
# 108       IND    Asia       Southern Asia
# 109       MWI  Africa  Sub-Saharan Africa
# 110       TZA  Africa  Sub-Saharan Africa
# 111       ZWE  Africa  Sub-Saharan Africa
# 112       AFG    Asia       Southern Asia
#
# [113 rows x 11 columns]

# %%
df6 = df_2020[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]

df6
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN           7.8087
# 1        Denmark  Europe     Northern Europe       DNK           7.6456
# 2    Switzerland  Europe      Western Europe       CHE           7.5599
# 3        Iceland  Europe     Northern Europe       ISL           7.5045
# 4         Norway  Europe     Northern Europe       NOR           7.4880
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND           3.5733
# 109       Malawi  Africa  Sub-Saharan Africa       MWI           3.5380
# 110     Tanzania  Africa  Sub-Saharan Africa       TZA           3.4762
# 111     Zimbabwe  Africa  Sub-Saharan Africa       ZWE           3.2992
# 112  Afghanistan    Asia       Southern Asia       AFG           2.5669
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.285190        1.499526        71.900825
# 1          1.326949        1.503449        72.402504
# 2          1.390774        1.472403        74.102448
# 3          1.326502        1.547567        73.000000
# 4          1.424207        1.495173        73.200783
# ..              ...             ...              ...
# 108        0.730576        0.644199        60.215187
# 109        0.176535        0.530368        57.592888
# 110        0.457163        0.872675        57.496075
# 111        0.425564        1.047835        55.617260
# 112        0.300706        0.356434        52.590000
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                        0.662317    0.159670                   0.195445
# 1                        0.665040    0.242793                   0.168489
# 2                        0.628954    0.269056                   0.303728
# 3                        0.661981    0.362330                   0.711710
# 4                        0.670201    0.287985                   0.263218
# ..                            ...         ...                        ...
# 108                      0.581142    0.237072                   0.772043
# 109                      0.487390    0.213185                   0.731701
# 110                      0.509343    0.271541                   0.619799
# 111                      0.377405    0.151349                   0.810237
# 112                      0.000000    0.135235                   0.933687
#
# [113 rows x 11 columns]

# %%
df7 = df_2021[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]

df7
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.842
# 1        Denmark  Europe     Northern Europe       DNK            7.620
# 2    Switzerland  Europe      Western Europe       CHE            7.571
# 3        Iceland  Europe     Northern Europe       ISL            7.554
# 4    Netherlands  Europe      Western Europe       NLD            7.464
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND            3.819
# 109     Tanzania  Africa  Sub-Saharan Africa       TZA            3.623
# 110       Malawi  Africa  Sub-Saharan Africa       MWI            3.600
# 111     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.145
# 112  Afghanistan    Asia       Southern Asia       AFG            2.523
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.446           1.106           72.000
# 1             1.502           1.108           72.700
# 2             1.566           1.079           74.400
# 3             1.482           1.172           73.000
# 4             1.501           1.079           72.400
# ..              ...             ...              ...
# 108           0.741           0.316           60.633
# 109           0.433           0.540           57.999
# 110           0.113           0.168           57.948
# 111           0.457           0.649           56.201
# 112           0.370           0.000           52.493
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.691       0.124                      0.186
# 1                           0.686       0.208                      0.179
# 2                           0.653       0.204                      0.292
# 3                           0.698       0.293                      0.673
# 4                           0.647       0.302                      0.338
# ..                            ...         ...                        ...
# 108                         0.622       0.246                      0.774
# 109                         0.549       0.307                      0.577
# 110                         0.484       0.213                      0.729
# 111                         0.359       0.157                      0.821
# 112                         0.000       0.122                      0.924
#
# [113 rows x 11 columns]

# %%
df8 = df_2022[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]

df8
# Out:
#           country  region          sub_region iso_alpha  happiness_score  \
# 0         Finland  Europe     Northern Europe       FIN            7.821
# 1         Denmark  Europe     Northern Europe       DNK            7.636
# 2         Iceland  Europe     Northern Europe       ISL            7.557
# 3     Switzerland  Europe      Western Europe       CHE            7.512
# 4     Netherlands  Europe      Western Europe       NLD            7.415
# ..            ...     ...                 ...       ...              ...
# 108      Tanzania  Africa  Sub-Saharan Africa       TZA            3.702
# 109  Sierra Leone  Africa  Sub-Saharan Africa       SLE            3.574
# 110      Zimbabwe  Africa  Sub-Saharan Africa       ZWE            2.995
# 111       Lebanon    Asia        Western Asia       LBN            2.955
# 112   Afghanistan    Asia       Southern Asia       AFG            2.404
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.892           1.258            0.775
# 1             1.953           1.243            0.777
# 2             1.936           1.320            0.803
# 3             2.026           1.226            0.822
# 4             1.945           1.206            0.787
# ..              ...             ...              ...
# 108           0.848           0.597            0.425
# 109           0.686           0.416            0.273
# 110           0.947           0.690            0.270
# 111           1.392           0.498            0.631
# 112           0.758           0.000            0.289
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.736       0.109                      0.534
# 1                           0.719       0.188                      0.532
# 2                           0.718       0.270                      0.191
# 3                           0.677       0.147                      0.461
# 4                           0.651       0.271                      0.419
# ..                            ...         ...                        ...
# 108                         0.578       0.248                      0.270
# 109                         0.387       0.202                      0.055
# 110                         0.329       0.106                      0.105
# 111                         0.103       0.082                      0.034
# 112                         0.000       0.089                      0.005
#
# [113 rows x 11 columns]

# %%
df_2023
# Out:
#           country  happiness_score  life_expectancy  \
# 0         Finland            7.804           71.150
# 1         Denmark            7.586           71.250
# 2         Iceland            7.530           72.050
# 3          Israel            7.473           72.697
# 4     Netherlands            7.403           71.550
# ..            ...              ...              ...
# 108        Malawi            3.495           58.475
# 109      Zimbabwe            3.204           54.050
# 110  Sierra Leone            3.138           54.900
# 111       Lebanon            2.392           66.149
# 112   Afghanistan            1.859           54.712
#
#      perceptions_of_corruption  gdp_per_capita  social_support  \
# 0                        0.182           1.888           1.585
# 1                        0.196           1.949           1.548
# 2                        0.668           1.926           1.620
# 3                        0.708           1.833           1.521
# 4                        0.379           1.942           1.488
# ..                         ...             ...             ...
# 108                      0.749           0.637           0.479
# 109                      0.766           0.758           0.881
# 110                      0.858           0.670           0.540
# 111                      0.891           1.417           0.476
# 112                      0.847           0.645           0.000
#
#      freedom_to_make_life_choices  generosity iso_alpha  region  \
# 0                           0.772       0.126       FIN  Europe
# 1                           0.734       0.208       DNK  Europe
# 2                           0.738       0.250       ISL  Europe
# 3                           0.569       0.124       ISR    Asia
# 4                           0.672       0.251       NLD  Europe
# ..                            ...         ...       ...     ...
# 108                         0.490       0.139       MWI  Africa
# 109                         0.363       0.112       ZWE  Africa
# 110                         0.371       0.193       SLE  Africa
# 111                         0.123       0.061       LBN    Asia
# 112                         0.000       0.093       AFG    Asia
#
#              sub_region
# 0       Northern Europe
# 1       Northern Europe
# 2       Northern Europe
# 3          Western Asia
# 4        Western Europe
# ..                  ...
# 108  Sub-Saharan Africa
# 109  Sub-Saharan Africa
# 110  Sub-Saharan Africa
# 111        Western Asia
# 112       Southern Asia
#
# [113 rows x 11 columns]

# %%
df9 = df_2023[["country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]

df9
# Out:
#           country  region          sub_region iso_alpha  happiness_score  \
# 0         Finland  Europe     Northern Europe       FIN            7.804
# 1         Denmark  Europe     Northern Europe       DNK            7.586
# 2         Iceland  Europe     Northern Europe       ISL            7.530
# 3          Israel    Asia        Western Asia       ISR            7.473
# 4     Netherlands  Europe      Western Europe       NLD            7.403
# ..            ...     ...                 ...       ...              ...
# 108        Malawi  Africa  Sub-Saharan Africa       MWI            3.495
# 109      Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.204
# 110  Sierra Leone  Africa  Sub-Saharan Africa       SLE            3.138
# 111       Lebanon    Asia        Western Asia       LBN            2.392
# 112   Afghanistan    Asia       Southern Asia       AFG            1.859
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.888           1.585           71.150
# 1             1.949           1.548           71.250
# 2             1.926           1.620           72.050
# 3             1.833           1.521           72.697
# 4             1.942           1.488           71.550
# ..              ...             ...              ...
# 108           0.637           0.479           58.475
# 109           0.758           0.881           54.050
# 110           0.670           0.540           54.900
# 111           1.417           0.476           66.149
# 112           0.645           0.000           54.712
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.772       0.126                      0.182
# 1                           0.734       0.208                      0.196
# 2                           0.738       0.250                      0.668
# 3                           0.569       0.124                      0.708
# 4                           0.672       0.251                      0.379
# ..                            ...         ...                        ...
# 108                         0.490       0.139                      0.749
# 109                         0.363       0.112                      0.766
# 110                         0.371       0.193                      0.858
# 111                         0.123       0.061                      0.891
# 112                         0.000       0.093                      0.847
#
# [113 rows x 11 columns]

# %%
df1['year']="2015"
df1
# Out:
#           country    region          sub_region iso_alpha  happiness_score  \
# 0     Switzerland    Europe      Western Europe       CHE            7.587
# 1         Iceland    Europe     Northern Europe       ISL            7.561
# 2         Denmark    Europe     Northern Europe       DNK            7.527
# 3          Norway    Europe     Northern Europe       NOR            7.522
# 4          Canada  Americas    Northern America       CAN            7.427
# ..            ...       ...                 ...       ...              ...
# 131        Guinea    Africa  Sub-Saharan Africa       GIN            3.656
# 132  Burkina Faso    Africa  Sub-Saharan Africa       BFA            3.587
# 133   Afghanistan      Asia       Southern Asia       AFG            3.575
# 135         Benin    Africa  Sub-Saharan Africa       BEN            3.340
# 138          Togo    Africa  Sub-Saharan Africa       TGO            2.839
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.39651         1.34951          0.94143
# 1           1.30232         1.40223          0.94784
# 2           1.32548         1.36058          0.87464
# 3           1.45900         1.33095          0.88521
# 4           1.32629         1.32261          0.90563
# ..              ...             ...              ...
# 131         0.17417         0.46475          0.24009
# 132         0.25812         0.85188          0.27125
# 133         0.31982         0.30285          0.30335
# 135         0.28665         0.35386          0.31910
# 138         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                         0.66557     0.29678                    0.41978  2015
# 1                         0.62877     0.43630                    0.14145  2015
# 2                         0.64938     0.34139                    0.48357  2015
# 3                         0.66973     0.34699                    0.36503  2015
# 4                         0.63297     0.45811                    0.32957  2015
# ..                            ...         ...                        ...   ...
# 131                       0.37725     0.28657                    0.12139  2015
# 132                       0.39493     0.21747                    0.12832  2015
# 133                       0.23414     0.36510                    0.09719  2015
# 135                       0.48450     0.18260                    0.08010  2015
# 138                       0.36453     0.16681                    0.10731  2015
#
# [113 rows x 12 columns]

# %%
df1 = df1[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df1
# Out:
#      year       country    region          sub_region iso_alpha  \
# 0    2015   Switzerland    Europe      Western Europe       CHE
# 1    2015       Iceland    Europe     Northern Europe       ISL
# 2    2015       Denmark    Europe     Northern Europe       DNK
# 3    2015        Norway    Europe     Northern Europe       NOR
# 4    2015        Canada  Americas    Northern America       CAN
# ..    ...           ...       ...                 ...       ...
# 131  2015        Guinea    Africa  Sub-Saharan Africa       GIN
# 132  2015  Burkina Faso    Africa  Sub-Saharan Africa       BFA
# 133  2015   Afghanistan      Asia       Southern Asia       AFG
# 135  2015         Benin    Africa  Sub-Saharan Africa       BEN
# 138  2015          Togo    Africa  Sub-Saharan Africa       TGO
#
#      happiness_score  gdp_per_capita  social_support  life_expectancy  \
# 0              7.587         1.39651         1.34951          0.94143
# 1              7.561         1.30232         1.40223          0.94784
# 2              7.527         1.32548         1.36058          0.87464
# 3              7.522         1.45900         1.33095          0.88521
# 4              7.427         1.32629         1.32261          0.90563
# ..               ...             ...             ...              ...
# 131            3.656         0.17417         0.46475          0.24009
# 132            3.587         0.25812         0.85188          0.27125
# 133            3.575         0.31982         0.30285          0.30335
# 135            3.340         0.28665         0.35386          0.31910
# 138            2.839         0.20868         0.13995          0.28443
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.66557     0.29678                    0.41978
# 1                         0.62877     0.43630                    0.14145
# 2                         0.64938     0.34139                    0.48357
# 3                         0.66973     0.34699                    0.36503
# 4                         0.63297     0.45811                    0.32957
# ..                            ...         ...                        ...
# 131                       0.37725     0.28657                    0.12139
# 132                       0.39493     0.21747                    0.12832
# 133                       0.23414     0.36510                    0.09719
# 135                       0.48450     0.18260                    0.08010
# 138                       0.36453     0.16681                    0.10731
#
# [113 rows x 12 columns]

# %%
df2['year']="2016"
df2
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Denmark  Europe     Northern Europe       DNK            7.526
# 1    Switzerland  Europe      Western Europe       CHE            7.509
# 2        Iceland  Europe     Northern Europe       ISL            7.501
# 3         Norway  Europe     Northern Europe       NOR            7.498
# 4        Finland  Europe     Northern Europe       FIN            7.413
# ..           ...     ...                 ...       ...              ...
# 130     Tanzania  Africa  Sub-Saharan Africa       TZA            3.666
# 132       Guinea  Africa  Sub-Saharan Africa       GIN            3.607
# 134        Benin  Africa  Sub-Saharan Africa       BEN            3.484
# 135  Afghanistan    Asia       Southern Asia       AFG            3.360
# 136         Togo  Africa  Sub-Saharan Africa       TGO            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.44178         1.16374          0.79504
# 1           1.52733         1.14524          0.86303
# 2           1.42666         1.18326          0.86733
# 3           1.57744         1.12690          0.79579
# 4           1.40598         1.13464          0.81091
# ..              ...             ...              ...
# 130         0.47155         0.77623          0.35700
# 132         0.22415         0.31090          0.18829
# 134         0.39499         0.10419          0.21028
# 135         0.38227         0.11037          0.17344
# 136         0.28123         0.00000          0.24811
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                         0.57941     0.36171                    0.44453  2016
# 1                         0.58557     0.28083                    0.41203  2016
# 2                         0.56624     0.47678                    0.14975  2016
# 3                         0.59609     0.37895                    0.35776  2016
# 4                         0.57104     0.25492                    0.41004  2016
# ..                            ...         ...                        ...   ...
# 130                       0.31760     0.31472                    0.05099  2016
# 132                       0.30953     0.29914                    0.11920  2016
# 134                       0.39747     0.20180                    0.06681  2016
# 135                       0.16430     0.31268                    0.07112  2016
# 136                       0.34678     0.17517                    0.11587  2016
#
# [113 rows x 12 columns]

# %%
df2 = df2[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df2
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2016      Denmark  Europe     Northern Europe       DNK            7.526
# 1    2016  Switzerland  Europe      Western Europe       CHE            7.509
# 2    2016      Iceland  Europe     Northern Europe       ISL            7.501
# 3    2016       Norway  Europe     Northern Europe       NOR            7.498
# 4    2016      Finland  Europe     Northern Europe       FIN            7.413
# ..    ...          ...     ...                 ...       ...              ...
# 130  2016     Tanzania  Africa  Sub-Saharan Africa       TZA            3.666
# 132  2016       Guinea  Africa  Sub-Saharan Africa       GIN            3.607
# 134  2016        Benin  Africa  Sub-Saharan Africa       BEN            3.484
# 135  2016  Afghanistan    Asia       Southern Asia       AFG            3.360
# 136  2016         Togo  Africa  Sub-Saharan Africa       TGO            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0           1.44178         1.16374          0.79504
# 1           1.52733         1.14524          0.86303
# 2           1.42666         1.18326          0.86733
# 3           1.57744         1.12690          0.79579
# 4           1.40598         1.13464          0.81091
# ..              ...             ...              ...
# 130         0.47155         0.77623          0.35700
# 132         0.22415         0.31090          0.18829
# 134         0.39499         0.10419          0.21028
# 135         0.38227         0.11037          0.17344
# 136         0.28123         0.00000          0.24811
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                         0.57941     0.36171                    0.44453
# 1                         0.58557     0.28083                    0.41203
# 2                         0.56624     0.47678                    0.14975
# 3                         0.59609     0.37895                    0.35776
# 4                         0.57104     0.25492                    0.41004
# ..                            ...         ...                        ...
# 130                       0.31760     0.31472                    0.05099
# 132                       0.30953     0.29914                    0.11920
# 134                       0.39747     0.20180                    0.06681
# 135                       0.16430     0.31268                    0.07112
# 136                       0.34678     0.17517                    0.11587
#
# [113 rows x 12 columns]

# %%
df3['year']="2017"
df3
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0         Norway  Europe     Northern Europe       NOR            7.537
# 1        Denmark  Europe     Northern Europe       DNK            7.522
# 2        Iceland  Europe     Northern Europe       ISL            7.504
# 3    Switzerland  Europe      Western Europe       CHE            7.494
# 4        Finland  Europe     Northern Europe       FIN            7.469
# ..           ...     ...                 ...       ...              ...
# 126  Afghanistan    Asia       Southern Asia       AFG            3.794
# 128        Benin  Africa  Sub-Saharan Africa       BEN            3.657
# 133       Guinea  Africa  Sub-Saharan Africa       GIN            3.507
# 134         Togo  Africa  Sub-Saharan Africa       TGO            3.495
# 137     Tanzania  Africa  Sub-Saharan Africa       TZA            3.349
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.616463        1.533524         0.796667
# 1          1.482383        1.551122         0.792566
# 2          1.480633        1.610574         0.833552
# 3          1.564980        1.516912         0.858131
# 4          1.443572        1.540247         0.809158
# ..              ...             ...              ...
# 126        0.401477        0.581543         0.180747
# 128        0.431085        0.435300         0.209930
# 133        0.244550        0.791245         0.194129
# 134        0.305445        0.431883         0.247106
# 137        0.511136        1.041990         0.364509
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                        0.635423    0.362012                   0.315964  2017
# 1                        0.626007    0.355280                   0.400770  2017
# 2                        0.627163    0.475540                   0.153527  2017
# 3                        0.620071    0.290549                   0.367007  2017
# 4                        0.617951    0.245483                   0.382612  2017
# ..                            ...         ...                        ...   ...
# 126                      0.106180    0.311871                   0.061158  2017
# 128                      0.425963    0.207948                   0.060929  2017
# 133                      0.348588    0.264815                   0.110938  2017
# 134                      0.380426    0.196896                   0.095665  2017
# 137                      0.390018    0.354256                   0.066035  2017
#
# [113 rows x 12 columns]

# %%
df3 = df3[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df3
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2017       Norway  Europe     Northern Europe       NOR            7.537
# 1    2017      Denmark  Europe     Northern Europe       DNK            7.522
# 2    2017      Iceland  Europe     Northern Europe       ISL            7.504
# 3    2017  Switzerland  Europe      Western Europe       CHE            7.494
# 4    2017      Finland  Europe     Northern Europe       FIN            7.469
# ..    ...          ...     ...                 ...       ...              ...
# 126  2017  Afghanistan    Asia       Southern Asia       AFG            3.794
# 128  2017        Benin  Africa  Sub-Saharan Africa       BEN            3.657
# 133  2017       Guinea  Africa  Sub-Saharan Africa       GIN            3.507
# 134  2017         Togo  Africa  Sub-Saharan Africa       TGO            3.495
# 137  2017     Tanzania  Africa  Sub-Saharan Africa       TZA            3.349
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.616463        1.533524         0.796667
# 1          1.482383        1.551122         0.792566
# 2          1.480633        1.610574         0.833552
# 3          1.564980        1.516912         0.858131
# 4          1.443572        1.540247         0.809158
# ..              ...             ...              ...
# 126        0.401477        0.581543         0.180747
# 128        0.431085        0.435300         0.209930
# 133        0.244550        0.791245         0.194129
# 134        0.305445        0.431883         0.247106
# 137        0.511136        1.041990         0.364509
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                        0.635423    0.362012                   0.315964
# 1                        0.626007    0.355280                   0.400770
# 2                        0.627163    0.475540                   0.153527
# 3                        0.620071    0.290549                   0.367007
# 4                        0.617951    0.245483                   0.382612
# ..                            ...         ...                        ...
# 126                      0.106180    0.311871                   0.061158
# 128                      0.425963    0.207948                   0.060929
# 133                      0.348588    0.264815                   0.110938
# 134                      0.380426    0.196896                   0.095665
# 137                      0.390018    0.354256                   0.066035
#
# [113 rows x 12 columns]

# %%
df4['year']="2018"
df4
# Out:
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.632
# 1         Norway  Europe     Northern Europe       NOR            7.594
# 2        Denmark  Europe     Northern Europe       DNK            7.555
# 3        Iceland  Europe     Northern Europe       ISL            7.495
# 4    Switzerland  Europe      Western Europe       CHE            7.487
# ..           ...     ...                 ...       ...              ...
# 108       Guinea  Africa  Sub-Saharan Africa       GIN            3.964
# 109     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.692
# 110  Afghanistan    Asia       Southern Asia       AFG            3.632
# 111       Malawi  Africa  Sub-Saharan Africa       MWI            3.587
# 112     Tanzania  Africa  Sub-Saharan Africa       TZA            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.305           1.592            0.874
# 1             1.456           1.582            0.861
# 2             1.351           1.590            0.868
# 3             1.343           1.644            0.914
# 4             1.420           1.549            0.927
# ..              ...             ...              ...
# 108           0.344           0.792            0.211
# 109           0.357           1.094            0.248
# 110           0.332           0.537            0.255
# 111           0.186           0.541            0.306
# 112           0.455           0.991            0.381
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                           0.681       0.202                      0.393  2018
# 1                           0.686       0.286                      0.340  2018
# 2                           0.683       0.284                      0.408  2018
# 3                           0.677       0.353                      0.138  2018
# 4                           0.660       0.256                      0.357  2018
# ..                            ...         ...                        ...   ...
# 108                         0.394       0.185                      0.094  2018
# 109                         0.406       0.132                      0.099  2018
# 110                         0.085       0.191                      0.036  2018
# 111                         0.531       0.210                      0.080  2018
# 112                         0.481       0.270                      0.097  2018
#
# [113 rows x 12 columns]

# %%
df4 = df4[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df4
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2018      Finland  Europe     Northern Europe       FIN            7.632
# 1    2018       Norway  Europe     Northern Europe       NOR            7.594
# 2    2018      Denmark  Europe     Northern Europe       DNK            7.555
# 3    2018      Iceland  Europe     Northern Europe       ISL            7.495
# 4    2018  Switzerland  Europe      Western Europe       CHE            7.487
# ..    ...          ...     ...                 ...       ...              ...
# 108  2018       Guinea  Africa  Sub-Saharan Africa       GIN            3.964
# 109  2018     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.692
# 110  2018  Afghanistan    Asia       Southern Asia       AFG            3.632
# 111  2018       Malawi  Africa  Sub-Saharan Africa       MWI            3.587
# 112  2018     Tanzania  Africa  Sub-Saharan Africa       TZA            3.303
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.305           1.592            0.874
# 1             1.456           1.582            0.861
# 2             1.351           1.590            0.868
# 3             1.343           1.644            0.914
# 4             1.420           1.549            0.927
# ..              ...             ...              ...
# 108           0.344           0.792            0.211
# 109           0.357           1.094            0.248
# 110           0.332           0.537            0.255
# 111           0.186           0.541            0.306
# 112           0.455           0.991            0.381
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.681       0.202                      0.393
# 1                           0.686       0.286                      0.340
# 2                           0.683       0.284                      0.408
# 3                           0.677       0.353                      0.138
# 4                           0.660       0.256                      0.357
# ..                            ...         ...                        ...
# 108                         0.394       0.185                      0.094
# 109                         0.406       0.132                      0.099
# 110                         0.085       0.191                      0.036
# 111                         0.531       0.210                      0.080
# 112                         0.481       0.270                      0.097
#
# [113 rows x 12 columns]

# %%
df5['year']="2019"
df5
# Out:
# /var/folders/r5/6w_bfh4n6p717hxdwjctkzmw0000gn/T/ipykernel_72925/801817142.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.769
# 1        Denmark  Europe     Northern Europe       DNK            7.600
# 2         Norway  Europe     Northern Europe       NOR            7.554
# 3        Iceland  Europe     Northern Europe       ISL            7.494
# 4    Netherlands  Europe      Western Europe       NLD            7.488
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND            4.015
# 109     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.663
# 110       Malawi  Africa  Sub-Saharan Africa       MWI            3.410
# 111     Tanzania  Africa  Sub-Saharan Africa       TZA            3.231
# 112  Afghanistan    Asia       Southern Asia       AFG            3.203
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.340           1.587            0.986
# 1             1.383           1.573            0.996
# 2             1.488           1.582            1.028
# 3             1.380           1.624            1.026
# 4             1.396           1.522            0.999
# ..              ...             ...              ...
# 108           0.755           0.765            0.588
# 109           0.366           1.114            0.433
# 110           0.191           0.560            0.495
# 111           0.476           0.885            0.499
# 112           0.350           0.517            0.361
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                           0.596       0.153                      0.393  2019
# 1                           0.592       0.252                      0.410  2019
# 2                           0.603       0.271                      0.341  2019
# 3                           0.591       0.354                      0.118  2019
# 4                           0.557       0.322                      0.298  2019
# ..                            ...         ...                        ...   ...
# 108                         0.498       0.200                      0.085  2019
# 109                         0.361       0.151                      0.089  2019
# 110                         0.443       0.218                      0.089  2019
# 111                         0.417       0.276                      0.147  2019
# 112                         0.000       0.158                      0.025  2019
#
# [113 rows x 12 columns]

# %%
df5 = df5[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df5
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2019      Finland  Europe     Northern Europe       FIN            7.769
# 1    2019      Denmark  Europe     Northern Europe       DNK            7.600
# 2    2019       Norway  Europe     Northern Europe       NOR            7.554
# 3    2019      Iceland  Europe     Northern Europe       ISL            7.494
# 4    2019  Netherlands  Europe      Western Europe       NLD            7.488
# ..    ...          ...     ...                 ...       ...              ...
# 108  2019        India    Asia       Southern Asia       IND            4.015
# 109  2019     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.663
# 110  2019       Malawi  Africa  Sub-Saharan Africa       MWI            3.410
# 111  2019     Tanzania  Africa  Sub-Saharan Africa       TZA            3.231
# 112  2019  Afghanistan    Asia       Southern Asia       AFG            3.203
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.340           1.587            0.986
# 1             1.383           1.573            0.996
# 2             1.488           1.582            1.028
# 3             1.380           1.624            1.026
# 4             1.396           1.522            0.999
# ..              ...             ...              ...
# 108           0.755           0.765            0.588
# 109           0.366           1.114            0.433
# 110           0.191           0.560            0.495
# 111           0.476           0.885            0.499
# 112           0.350           0.517            0.361
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 108                         0.498       0.200                      0.085
# 109                         0.361       0.151                      0.089
# 110                         0.443       0.218                      0.089
# 111                         0.417       0.276                      0.147
# 112                         0.000       0.158                      0.025
#
# [113 rows x 12 columns]

# %%
df6['year']="2020"
df6
# Out:
# /var/folders/r5/6w_bfh4n6p717hxdwjctkzmw0000gn/T/ipykernel_72925/2769413418.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN           7.8087
# 1        Denmark  Europe     Northern Europe       DNK           7.6456
# 2    Switzerland  Europe      Western Europe       CHE           7.5599
# 3        Iceland  Europe     Northern Europe       ISL           7.5045
# 4         Norway  Europe     Northern Europe       NOR           7.4880
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND           3.5733
# 109       Malawi  Africa  Sub-Saharan Africa       MWI           3.5380
# 110     Tanzania  Africa  Sub-Saharan Africa       TZA           3.4762
# 111     Zimbabwe  Africa  Sub-Saharan Africa       ZWE           3.2992
# 112  Afghanistan    Asia       Southern Asia       AFG           2.5669
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.285190        1.499526        71.900825
# 1          1.326949        1.503449        72.402504
# 2          1.390774        1.472403        74.102448
# 3          1.326502        1.547567        73.000000
# 4          1.424207        1.495173        73.200783
# ..              ...             ...              ...
# 108        0.730576        0.644199        60.215187
# 109        0.176535        0.530368        57.592888
# 110        0.457163        0.872675        57.496075
# 111        0.425564        1.047835        55.617260
# 112        0.300706        0.356434        52.590000
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                        0.662317    0.159670                   0.195445  2020
# 1                        0.665040    0.242793                   0.168489  2020
# 2                        0.628954    0.269056                   0.303728  2020
# 3                        0.661981    0.362330                   0.711710  2020
# 4                        0.670201    0.287985                   0.263218  2020
# ..                            ...         ...                        ...   ...
# 108                      0.581142    0.237072                   0.772043  2020
# 109                      0.487390    0.213185                   0.731701  2020
# 110                      0.509343    0.271541                   0.619799  2020
# 111                      0.377405    0.151349                   0.810237  2020
# 112                      0.000000    0.135235                   0.933687  2020
#
# [113 rows x 12 columns]

# %%
df6 = df6[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df6
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2020      Finland  Europe     Northern Europe       FIN           7.8087
# 1    2020      Denmark  Europe     Northern Europe       DNK           7.6456
# 2    2020  Switzerland  Europe      Western Europe       CHE           7.5599
# 3    2020      Iceland  Europe     Northern Europe       ISL           7.5045
# 4    2020       Norway  Europe     Northern Europe       NOR           7.4880
# ..    ...          ...     ...                 ...       ...              ...
# 108  2020        India    Asia       Southern Asia       IND           3.5733
# 109  2020       Malawi  Africa  Sub-Saharan Africa       MWI           3.5380
# 110  2020     Tanzania  Africa  Sub-Saharan Africa       TZA           3.4762
# 111  2020     Zimbabwe  Africa  Sub-Saharan Africa       ZWE           3.2992
# 112  2020  Afghanistan    Asia       Southern Asia       AFG           2.5669
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0          1.285190        1.499526        71.900825
# 1          1.326949        1.503449        72.402504
# 2          1.390774        1.472403        74.102448
# 3          1.326502        1.547567        73.000000
# 4          1.424207        1.495173        73.200783
# ..              ...             ...              ...
# 108        0.730576        0.644199        60.215187
# 109        0.176535        0.530368        57.592888
# 110        0.457163        0.872675        57.496075
# 111        0.425564        1.047835        55.617260
# 112        0.300706        0.356434        52.590000
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                        0.662317    0.159670                   0.195445
# 1                        0.665040    0.242793                   0.168489
# 2                        0.628954    0.269056                   0.303728
# 3                        0.661981    0.362330                   0.711710
# 4                        0.670201    0.287985                   0.263218
# ..                            ...         ...                        ...
# 108                      0.581142    0.237072                   0.772043
# 109                      0.487390    0.213185                   0.731701
# 110                      0.509343    0.271541                   0.619799
# 111                      0.377405    0.151349                   0.810237
# 112                      0.000000    0.135235                   0.933687
#
# [113 rows x 12 columns]

# %%
df7['year']="2021"
df7
# Out:
# /var/folders/r5/6w_bfh4n6p717hxdwjctkzmw0000gn/T/ipykernel_72925/2575769348.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          country  region          sub_region iso_alpha  happiness_score  \
# 0        Finland  Europe     Northern Europe       FIN            7.842
# 1        Denmark  Europe     Northern Europe       DNK            7.620
# 2    Switzerland  Europe      Western Europe       CHE            7.571
# 3        Iceland  Europe     Northern Europe       ISL            7.554
# 4    Netherlands  Europe      Western Europe       NLD            7.464
# ..           ...     ...                 ...       ...              ...
# 108        India    Asia       Southern Asia       IND            3.819
# 109     Tanzania  Africa  Sub-Saharan Africa       TZA            3.623
# 110       Malawi  Africa  Sub-Saharan Africa       MWI            3.600
# 111     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.145
# 112  Afghanistan    Asia       Southern Asia       AFG            2.523
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.446           1.106           72.000
# 1             1.502           1.108           72.700
# 2             1.566           1.079           74.400
# 3             1.482           1.172           73.000
# 4             1.501           1.079           72.400
# ..              ...             ...              ...
# 108           0.741           0.316           60.633
# 109           0.433           0.540           57.999
# 110           0.113           0.168           57.948
# 111           0.457           0.649           56.201
# 112           0.370           0.000           52.493
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                           0.691       0.124                      0.186  2021
# 1                           0.686       0.208                      0.179  2021
# 2                           0.653       0.204                      0.292  2021
# 3                           0.698       0.293                      0.673  2021
# 4                           0.647       0.302                      0.338  2021
# ..                            ...         ...                        ...   ...
# 108                         0.622       0.246                      0.774  2021
# 109                         0.549       0.307                      0.577  2021
# 110                         0.484       0.213                      0.729  2021
# 111                         0.359       0.157                      0.821  2021
# 112                         0.000       0.122                      0.924  2021
#
# [113 rows x 12 columns]

# %%
df7 = df7[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df7
# Out:
#      year      country  region          sub_region iso_alpha  happiness_score  \
# 0    2021      Finland  Europe     Northern Europe       FIN            7.842
# 1    2021      Denmark  Europe     Northern Europe       DNK            7.620
# 2    2021  Switzerland  Europe      Western Europe       CHE            7.571
# 3    2021      Iceland  Europe     Northern Europe       ISL            7.554
# 4    2021  Netherlands  Europe      Western Europe       NLD            7.464
# ..    ...          ...     ...                 ...       ...              ...
# 108  2021        India    Asia       Southern Asia       IND            3.819
# 109  2021     Tanzania  Africa  Sub-Saharan Africa       TZA            3.623
# 110  2021       Malawi  Africa  Sub-Saharan Africa       MWI            3.600
# 111  2021     Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.145
# 112  2021  Afghanistan    Asia       Southern Asia       AFG            2.523
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.446           1.106           72.000
# 1             1.502           1.108           72.700
# 2             1.566           1.079           74.400
# 3             1.482           1.172           73.000
# 4             1.501           1.079           72.400
# ..              ...             ...              ...
# 108           0.741           0.316           60.633
# 109           0.433           0.540           57.999
# 110           0.113           0.168           57.948
# 111           0.457           0.649           56.201
# 112           0.370           0.000           52.493
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.691       0.124                      0.186
# 1                           0.686       0.208                      0.179
# 2                           0.653       0.204                      0.292
# 3                           0.698       0.293                      0.673
# 4                           0.647       0.302                      0.338
# ..                            ...         ...                        ...
# 108                         0.622       0.246                      0.774
# 109                         0.549       0.307                      0.577
# 110                         0.484       0.213                      0.729
# 111                         0.359       0.157                      0.821
# 112                         0.000       0.122                      0.924
#
# [113 rows x 12 columns]

# %%
df8['year']="2022"
df8
# Out:
# /var/folders/r5/6w_bfh4n6p717hxdwjctkzmw0000gn/T/ipykernel_72925/2519669904.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           country  region          sub_region iso_alpha  happiness_score  \
# 0         Finland  Europe     Northern Europe       FIN            7.821
# 1         Denmark  Europe     Northern Europe       DNK            7.636
# 2         Iceland  Europe     Northern Europe       ISL            7.557
# 3     Switzerland  Europe      Western Europe       CHE            7.512
# 4     Netherlands  Europe      Western Europe       NLD            7.415
# ..            ...     ...                 ...       ...              ...
# 108      Tanzania  Africa  Sub-Saharan Africa       TZA            3.702
# 109  Sierra Leone  Africa  Sub-Saharan Africa       SLE            3.574
# 110      Zimbabwe  Africa  Sub-Saharan Africa       ZWE            2.995
# 111       Lebanon    Asia        Western Asia       LBN            2.955
# 112   Afghanistan    Asia       Southern Asia       AFG            2.404
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.892           1.258            0.775
# 1             1.953           1.243            0.777
# 2             1.936           1.320            0.803
# 3             2.026           1.226            0.822
# 4             1.945           1.206            0.787
# ..              ...             ...              ...
# 108           0.848           0.597            0.425
# 109           0.686           0.416            0.273
# 110           0.947           0.690            0.270
# 111           1.392           0.498            0.631
# 112           0.758           0.000            0.289
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                           0.736       0.109                      0.534  2022
# 1                           0.719       0.188                      0.532  2022
# 2                           0.718       0.270                      0.191  2022
# 3                           0.677       0.147                      0.461  2022
# 4                           0.651       0.271                      0.419  2022
# ..                            ...         ...                        ...   ...
# 108                         0.578       0.248                      0.270  2022
# 109                         0.387       0.202                      0.055  2022
# 110                         0.329       0.106                      0.105  2022
# 111                         0.103       0.082                      0.034  2022
# 112                         0.000       0.089                      0.005  2022
#
# [113 rows x 12 columns]

# %% [markdown]
# # Rearranging the columns

# %%
df8 = df8[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df8
# Out:
#      year       country  region          sub_region iso_alpha  \
# 0    2022       Finland  Europe     Northern Europe       FIN
# 1    2022       Denmark  Europe     Northern Europe       DNK
# 2    2022       Iceland  Europe     Northern Europe       ISL
# 3    2022   Switzerland  Europe      Western Europe       CHE
# 4    2022   Netherlands  Europe      Western Europe       NLD
# ..    ...           ...     ...                 ...       ...
# 108  2022      Tanzania  Africa  Sub-Saharan Africa       TZA
# 109  2022  Sierra Leone  Africa  Sub-Saharan Africa       SLE
# 110  2022      Zimbabwe  Africa  Sub-Saharan Africa       ZWE
# 111  2022       Lebanon    Asia        Western Asia       LBN
# 112  2022   Afghanistan    Asia       Southern Asia       AFG
#
#      happiness_score  gdp_per_capita  social_support  life_expectancy  \
# 0              7.821           1.892           1.258            0.775
# 1              7.636           1.953           1.243            0.777
# 2              7.557           1.936           1.320            0.803
# 3              7.512           2.026           1.226            0.822
# 4              7.415           1.945           1.206            0.787
# ..               ...             ...             ...              ...
# 108            3.702           0.848           0.597            0.425
# 109            3.574           0.686           0.416            0.273
# 110            2.995           0.947           0.690            0.270
# 111            2.955           1.392           0.498            0.631
# 112            2.404           0.758           0.000            0.289
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.736       0.109                      0.534
# 1                           0.719       0.188                      0.532
# 2                           0.718       0.270                      0.191
# 3                           0.677       0.147                      0.461
# 4                           0.651       0.271                      0.419
# ..                            ...         ...                        ...
# 108                         0.578       0.248                      0.270
# 109                         0.387       0.202                      0.055
# 110                         0.329       0.106                      0.105
# 111                         0.103       0.082                      0.034
# 112                         0.000       0.089                      0.005
#
# [113 rows x 12 columns]

# %%
df9['year']="2023"
df9
# Out:
# /var/folders/r5/6w_bfh4n6p717hxdwjctkzmw0000gn/T/ipykernel_72925/3009437957.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           country  region          sub_region iso_alpha  happiness_score  \
# 0         Finland  Europe     Northern Europe       FIN            7.804
# 1         Denmark  Europe     Northern Europe       DNK            7.586
# 2         Iceland  Europe     Northern Europe       ISL            7.530
# 3          Israel    Asia        Western Asia       ISR            7.473
# 4     Netherlands  Europe      Western Europe       NLD            7.403
# ..            ...     ...                 ...       ...              ...
# 108        Malawi  Africa  Sub-Saharan Africa       MWI            3.495
# 109      Zimbabwe  Africa  Sub-Saharan Africa       ZWE            3.204
# 110  Sierra Leone  Africa  Sub-Saharan Africa       SLE            3.138
# 111       Lebanon    Asia        Western Asia       LBN            2.392
# 112   Afghanistan    Asia       Southern Asia       AFG            1.859
#
#      gdp_per_capita  social_support  life_expectancy  \
# 0             1.888           1.585           71.150
# 1             1.949           1.548           71.250
# 2             1.926           1.620           72.050
# 3             1.833           1.521           72.697
# 4             1.942           1.488           71.550
# ..              ...             ...              ...
# 108           0.637           0.479           58.475
# 109           0.758           0.881           54.050
# 110           0.670           0.540           54.900
# 111           1.417           0.476           66.149
# 112           0.645           0.000           54.712
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption  year
# 0                           0.772       0.126                      0.182  2023
# 1                           0.734       0.208                      0.196  2023
# 2                           0.738       0.250                      0.668  2023
# 3                           0.569       0.124                      0.708  2023
# 4                           0.672       0.251                      0.379  2023
# ..                            ...         ...                        ...   ...
# 108                         0.490       0.139                      0.749  2023
# 109                         0.363       0.112                      0.766  2023
# 110                         0.371       0.193                      0.858  2023
# 111                         0.123       0.061                      0.891  2023
# 112                         0.000       0.093                      0.847  2023
#
# [113 rows x 12 columns]

# %%
df9 = df9[["year","country","region","sub_region","iso_alpha","happiness_score","gdp_per_capita","social_support","life_expectancy","freedom_to_make_life_choices","generosity","perceptions_of_corruption"]]
df9
# Out:
#      year       country  region          sub_region iso_alpha  \
# 0    2023       Finland  Europe     Northern Europe       FIN
# 1    2023       Denmark  Europe     Northern Europe       DNK
# 2    2023       Iceland  Europe     Northern Europe       ISL
# 3    2023        Israel    Asia        Western Asia       ISR
# 4    2023   Netherlands  Europe      Western Europe       NLD
# ..    ...           ...     ...                 ...       ...
# 108  2023        Malawi  Africa  Sub-Saharan Africa       MWI
# 109  2023      Zimbabwe  Africa  Sub-Saharan Africa       ZWE
# 110  2023  Sierra Leone  Africa  Sub-Saharan Africa       SLE
# 111  2023       Lebanon    Asia        Western Asia       LBN
# 112  2023   Afghanistan    Asia       Southern Asia       AFG
#
#      happiness_score  gdp_per_capita  social_support  life_expectancy  \
# 0              7.804           1.888           1.585           71.150
# 1              7.586           1.949           1.548           71.250
# 2              7.530           1.926           1.620           72.050
# 3              7.473           1.833           1.521           72.697
# 4              7.403           1.942           1.488           71.550
# ..               ...             ...             ...              ...
# 108            3.495           0.637           0.479           58.475
# 109            3.204           0.758           0.881           54.050
# 110            3.138           0.670           0.540           54.900
# 111            2.392           1.417           0.476           66.149
# 112            1.859           0.645           0.000           54.712
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.772       0.126                      0.182
# 1                           0.734       0.208                      0.196
# 2                           0.738       0.250                      0.668
# 3                           0.569       0.124                      0.708
# 4                           0.672       0.251                      0.379
# ..                            ...         ...                        ...
# 108                         0.490       0.139                      0.749
# 109                         0.363       0.112                      0.766
# 110                         0.371       0.193                      0.858
# 111                         0.123       0.061                      0.891
# 112                         0.000       0.093                      0.847
#
# [113 rows x 12 columns]

# %%
# Happiest and Unhappiest Countries for Year 2023 
top10 = df9.set_index('country')['happiness_score'].nlargest(10).to_frame()
bottom10 = df9.set_index('country')['happiness_score'].nsmallest(10).to_frame()
dfconcat = pd.concat([top10, bottom10], axis=0)
dfconcat = dfconcat.sort_values(by="happiness_score")

fig = plt.figure(figsize=(10,8))
cmap = plt.cm.RdYlGn
norm = plt.Normalize(vmin=dfconcat['happiness_score'].min(), vmax=dfconcat['happiness_score'].max())
colors = [cmap(norm(value)) for value in dfconcat['happiness_score']]

g = plt.barh(y=dfconcat.index, width=dfconcat["happiness_score"], color= colors)
plt.ylabel("Country")
plt.xlabel("Happiness Score")
plt.title("10 happiest and least happiest Countries", fontsize = 20)

plt.show()

# %% [markdown]
# # Interactive Sunburst Chart Using Plotly express library

# %%
fig = px.sunburst(data_frame= df9,
                  path=["region", "sub_region", "country"],
                  values="happiness_score",
                  color="happiness_score",
                  color_continuous_scale='RdYlGn',
                  width=900, 
                  height=900,
                  title = 'Happiness score sunburst - region / sub region / country')
fig.show()
# Out:
# <div>                            <div id="d9ee27af-0849-4480-a4da-b335151c8689" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9ee27af-0849-4480-a4da-b335151c8689")) {                    Plotly.newPlot(                        "d9ee27af-0849-4480-a4da-b335151c8689",                        [{"branchvalues":"total","customdata":[[1.859],[5.277],[5.329],[6.024],[5.342],[7.095],[7.097000000000001],[6.173000000000001],[4.282],[6.859],[4.374],[5.684],[6.125],[5.466],[4.638],[4.393],[4.973],[6.961],[6.334],[5.818],[5.63],[6.609],[6.125],[6.130000000000001],[7.586],[5.569],[5.559],[4.17],[6.122],[6.455],[4.091],[7.804],[6.661],[5.035],[5.109],[6.892],[4.605],[5.931],[5.072],[6.023],[6.041],[7.53],[4.036],[5.277],[4.876],[4.941],[6.911],[7.473],[6.405],[5.703000000000001],[6.129],[4.12],[6.144],[4.487],[5.824999999999999],[6.213],[2.392],[6.763],[3.495],[6.012],[4.198],[6.3],[5.902],[6.33],[5.818999999999999],[5.839999999999999],[5.722000000000001],[4.903],[4.372],[5.36],[7.403],[7.123],[6.259],[4.981],[7.315],[4.555],[6.265],[5.738000000000001],[5.526],[5.523],[6.26],[5.968],[6.589],[5.661],[6.463],[4.855],[6.144],[3.1379999999999995],[6.587],[6.469],[6.65],[5.275],[5.951],[6.435999999999999],[4.442],[7.395],[7.24],[5.33],[3.694],[5.842999999999999],[4.137],[4.497],[4.432],[5.071],[6.570999999999999],[6.796],[6.894],[6.494],[6.014],[5.211],[5.762999999999999],[3.9820000000000007],[3.204],[7.109027570685047],[5.844655642774416],[5.93705307945067],[5.961753672745693],[5.979994785690968],[4.764779035927826],[6.927661999278239],[7.111972388650237],[5.566566643819968],[4.456479632777966],[6.119045572361298],[4.536360649444495],[5.816159630076397],[7.0341593281457575],[4.576529995254358],[6.088452816785066],[5.545338643573694],[6.577294729134841],[7.109027570685047]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ehappiness_score_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003ehappiness_score=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Asia\u002fSouthern Asia\u002fAfghanistan","Europe\u002fSouthern Europe\u002fAlbania","Africa\u002fNorthern Africa\u002fAlgeria","Americas\u002fLatin America and the Caribbean\u002fArgentina","Asia\u002fWestern Asia\u002fArmenia","Oceania\u002fAustralia and New Zealand\u002fAustralia","Europe\u002fWestern Europe\u002fAustria","Asia\u002fWestern Asia\u002fBahrain","Asia\u002fSouthern Asia\u002fBangladesh","Europe\u002fWestern Europe\u002fBelgium","Africa\u002fSub-Saharan Africa\u002fBenin","Americas\u002fLatin America and the Caribbean\u002fBolivia","Americas\u002fLatin America and the Caribbean\u002fBrazil","Europe\u002fEastern Europe\u002fBulgaria","Africa\u002fSub-Saharan Africa\u002fBurkina Faso","Asia\u002fSouth-eastern Asia\u002fCambodia","Africa\u002fSub-Saharan Africa\u002fCameroon","Americas\u002fNorthern America\u002fCanada","Americas\u002fLatin America and the Caribbean\u002fChile","Asia\u002fEastern Asia\u002fChina","Americas\u002fLatin America and the Caribbean\u002fColombia","Americas\u002fLatin America and the Caribbean\u002fCosta Rica","Europe\u002fSouthern Europe\u002fCroatia","Asia\u002fWestern Asia\u002fCyprus","Europe\u002fNorthern Europe\u002fDenmark","Americas\u002fLatin America and the Caribbean\u002fDominican Republic","Americas\u002fLatin America and the Caribbean\u002fEcuador","Africa\u002fNorthern Africa\u002fEgypt","Americas\u002fLatin America and the Caribbean\u002fEl Salvador","Europe\u002fNorthern Europe\u002fEstonia","Africa\u002fSub-Saharan Africa\u002fEthiopia","Europe\u002fNorthern Europe\u002fFinland","Europe\u002fWestern Europe\u002fFrance","Africa\u002fSub-Saharan Africa\u002fGabon","Asia\u002fWestern Asia\u002fGeorgia","Europe\u002fWestern Europe\u002fGerma ...

# %% [markdown]
# # Exporting Final Dataframes in to CSVs in resources folder

# %%
df1.to_csv("./resources/whr_2015.csv", index = False)

# %%
df2.to_csv("./resources/whr_2016.csv", index = False)

# %%
df3.to_csv("./resources/whr_2017.csv", index = False)

# %%
df4.to_csv("./resources/whr_2018.csv", index = False)

# %%
df5.to_csv("./resources/whr_2019.csv", index = False)

# %%
df6.to_csv("./resources/whr_2020.csv", index = False)

# %%
df7.to_csv("./resources/whr_2021.csv", index = False)

# %%
df8.to_csv("./resources/whr_2022.csv", index = False)

# %%
df9.to_csv("./resources/whr_2023.csv", index = False)

# %%
#importes all the CSVs TO MongoDB through graphic user interface in mongo compass and validating now

# %%
#Validation
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017")
db = client.world_happiness_db

collection = db.whr

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('655ef2ec2801cf86d5533b6f'),
#  'year': 2015,
#  'country': 'Switzerland',
#  'region': 'Europe',
#  'sub_region': 'Western Europe',
#  'iso_alpha': 'CHE',
#  'happiness_score': 7.587,
#  'gdp_per_capita': 1.39651,
#  'social_support': 1.34951,
#  'life_expectancy': 0.94143,
#  'freedom_to_make_life_choices': 0.66557,
#  'generosity': 0.29678,
#  'perceptions_of_corruption': 0.41978}

# %%
list(collection.find_one({}))
# Out:
# ['_id',
#  'year',
#  'country',
#  'region',
#  'sub_region',
#  'iso_alpha',
#  'happiness_score',
#  'gdp_per_capita',
#  'social_support',
#  'life_expectancy',
#  'freedom_to_make_life_choices',
#  'generosity',
#  'perceptions_of_corruption']

# %%
result = list(collection.find({}).limit(10))
result
# Out:
# [{'_id': ObjectId('655ef2ec2801cf86d5533b6f'),
#   'year': 2015,
#   'country': 'Switzerland',
#   'region': 'Europe',
#   'sub_region': 'Western Europe',
#   'iso_alpha': 'CHE',
#   'happiness_score': 7.587,
#   'gdp_per_capita': 1.39651,
#   'social_support': 1.34951,
#   'life_expectancy': 0.94143,
#   'freedom_to_make_life_choices': 0.66557,
#   'generosity': 0.29678,
#   'perceptions_of_corruption': 0.41978},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b70'),
#   'year': 2015,
#   'country': 'Iceland',
#   'region': 'Europe',
#   'sub_region': 'Northern Europe',
#   'iso_alpha': 'ISL',
#   'happiness_score': 7.561,
#   'gdp_per_capita': 1.30232,
#   'social_support': 1.40223,
#   'life_expectancy': 0.94784,
#   'freedom_to_make_life_choices': 0.62877,
#   'generosity': 0.4363,
#   'perceptions_of_corruption': 0.14145},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b71'),
#   'year': 2015,
#   'country': 'Denmark',
#   'region': 'Europe',
#   'sub_region': 'Northern Europe',
#   'iso_alpha': 'DNK',
#   'happiness_score': 7.527,
#   'gdp_per_capita': 1.32548,
#   'social_support': 1.36058,
#   'life_expectancy': 0.87464,
#   'freedom_to_make_life_choices': 0.64938,
#   'generosity': 0.34139,
#   'perceptions_of_corruption': 0.48357},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b72'),
#   'year': 2015,
#   'country': 'Norway',
#   'region': 'Europe',
#   'sub_region': 'Northern Europe',
#   'iso_alpha': 'NOR',
#   'happiness_score': 7.522,
#   'gdp_per_capita': 1.459,
#   'social_support': 1.33095,
#   'life_expectancy': 0.88521,
#   'freedom_to_make_life_choices': 0.66973,
#   'generosity': 0.34699,
#   'perceptions_of_corruption': 0.36503},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b73'),
#   'year': 2015,
#   'country': 'Canada',
#   'region': 'Americas',
#   'sub_region': 'Northern America',
#   'iso_alpha': 'CAN',
#   'happiness_score': 7.427,
#   'gdp_per_capita': 1.32629,
#   'social_support': 1.32261,
#   'life_expectancy': 0.90563,
#   'freedom_to_make_life_choices': 0.63297,
#   'generosity': 0.45811,
#   'perceptions_of_corruption': 0.32957},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b74'),
#   'year': 2015,
#   'country': 'Finland',
#   'region': 'Europe',
#   'sub_region': 'Northern Europe',
#   'iso_alpha': 'FIN',
#   'happiness_score': 7.406,
#   'gdp_per_capita': 1.29025,
#   'social_support': 1.31826,
#   'life_expectancy': 0.88911,
#   'freedom_to_make_life_choices': 0.64169,
#   'generosity': 0.23351,
#   'perceptions_of_corruption': 0.41372},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b75'),
#   'year': 2015,
#   'country': 'Netherlands',
#   'region': 'Europe',
#   'sub_region': 'Western Europe',
#   'iso_alpha': 'NLD',
#   'happiness_score': 7.378,
#   'gdp_per_capita': 1.32944,
#   'social_support': 1.28017,
#   'life_expectancy': 0.89284,
#   'freedom_to_make_life_choices': 0.61576,
#   'generosity': 0.4761,
#   'perceptions_of_corruption': 0.31814},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b76'),
#   'year': 2015,
#   'country': 'Sweden',
#   'region': 'Europe',
#   'sub_region': 'Northern Europe',
#   'iso_alpha': 'SWE',
#   'happiness_score': 7.364,
#   'gdp_per_capita': 1.33171,
#   'social_support': 1.28907,
#   'life_expectancy': 0.91087,
#   'freedom_to_make_life_choices': 0.6598,
#   'generosity': 0.36262,
#   'perceptions_of_corruption': 0.43844},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b77'),
#   'year': 2015,
#   'country': 'New Zealand',
#   'region': 'Oceania',
#   'sub_region': 'Australia and New Zealand',
#   'iso_alpha': 'NZL',
#   'happiness_score': 7.286,
#   'gdp_per_capita': 1.25018,
#   'social_support': 1.31967,
#   'life_expectancy': 0.90837,
#   'freedom_to_make_life_choices': 0.63938,
#   'generosity': 0.47501,
#   'perceptions_of_corruption': 0.42922},
#  {'_id': ObjectId('655ef2ec2801cf86d5533b78'),
#   'year': 2015,
#   'country': 'Australia',
#   'region': 'Oceania',
#   'sub_region': 'Australia and New Zealand',
#   'iso_alpha': 'AUS',
#   'happiness_score': 7.284,
#   'gdp_per_capita': 1.33358,
#   'social_support': 1.30923,
#   'life_expectancy': 0.93156,
#   'freedom_to_make_life_choices': 0.65124,
#   'generosity': 0.43562,
#   'perceptions_of_corruption': 0.35637}]
